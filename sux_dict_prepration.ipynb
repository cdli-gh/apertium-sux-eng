# %%
import xml.etree.cElementTree as ET
import os
import re
import pandas as pd
import json
import random
random.seed(0)

import warnings
warnings.filterwarnings('ignore')

# %%
# tag_mapper = {'nu':'num', 'v':'vblex', 'cnj':'cnjcoo','3':'p3','2':'p2','1':'p1','':'None','s':'subj','p':'obj','a':'subj'}
tag_mapper = {'nu':'num', 'v':'vblex', 'cnj':'cnjcoo'}
NER_LIST = ['pn', 'on', 'fn', 'mn', 'sn', 'dn', 'gn', 'tn', 'wn', 'en', 'an', 'rn']

# %%
#for i in NER_LIST:
#    print(i,end = " ")

# %%
def txt_file_write(filename,list_data,mode="a"):
    with open(filename, mode) as f:
        for line in list_data:
            f.write("%s\n" %line)

# %%
def txt_file_read(filename):
    lines=[]
    with open(filename, "r") as f:
        for line in f:
            line=line.strip()
            lines.append(line)
    return lines

# %%
def json_file_read(filename):
    with open(filename) as f:
        data = json.load(f)
    return data

# %%
def save_json(filename,data):
    with open(filename, 'w') as f:
        json.dump(data, f,indent=2)

# %%
def process_row(row):
    orignal = row[1]
    segm = row[2]
    xpostag = row[3]
    lem = "_"
    eng_translation = "_"
    # match pattern - all groups starting with word and containing square bracket

    start_index = segm.find('[')
    end_index = segm.find(']')
    lem = segm[:start_index]
    eng_translation = segm[start_index+1:end_index]
    # for syntax corpus
    eng_translation = eng_translation.replace('.','_')
    
    if eng_translation=='1':
        eng_translation = lem

    # process and save the tags 
    org_tag_spl = re.split("\.|\|",xpostag)
    mp_tags_spl = []
    ner_tag=False
    for t in org_tag_spl:
        t=t.lower()
        mp_tag = t
        if t in tag_mapper.keys():
            mp_tag = tag_mapper[t]
        if t in NER_LIST:
            ner_tag=True
        mp_tags_spl.append(mp_tag)
    if ner_tag:
        mp_tags_spl.append('np')

    return lem,eng_translation,org_tag_spl, mp_tags_spl

# %%
# s = 'N.DEM2.ABS'
# org_tag_spl = re.split("\.|\-",s)
# org_tag_spl

# %% [markdown]
# # Extracting data from Directory

# %%
# define dataframe
column = ['filename','id','form','seg','xpostag','lem','eng_translation','org_tags_split', 'processed_tags_split']
extracted_df = pd.DataFrame(columns = column)
extracted_df.head()
# Out:
# Empty DataFrame
# Columns: [filename, id, form, seg, xpostag, lem, eng_translation, org_tags_split, processed_tags_split]
# Index: []

# %%
base_dir = 'data/consolidated/all_data/'
conll_files = os.listdir(base_dir)

# %%
for conll_file in conll_files:
    temp = os.path.join(base_dir,conll_file)
    f = txt_file_read(temp)
    f_lines = [line.split("\t") for line in f]


    # start processing file
    processed_ls = []
    for row in f_lines:
        row_len = len(row)
        if len(row)==8:
            # for syntax corpus
            row = row[:3] + row[4:]
        if len(row)==7 and row[1]!='' and row[2]!='SEGM' and row[3]!='_' and row[3]!='':
            lem,eng_translation,org_tag_spl, mp_tags_spl = process_row(row)
            processed_ls.append([conll_file, row[0], row[1], row[2], row[3], lem,eng_translation,org_tag_spl, mp_tags_spl])

        # print(orignal, lem,eng_translation,tags)
        # if orignal!="_" and lem!="_":
        
    processed_df = pd.DataFrame(processed_ls, columns=column)
    # print(processed_df)
    extracted_df = extracted_df.append(processed_df)

extracted_df = extracted_df.reset_index(inplace=False,drop=True)

# %%
extracted_df
# Out:
#             filename  id                  form                         seg  \
# 0      P432211.conll   1           mu-na-gi-in  _[he.standardized.for.him]
# 1      P432254.conll   2                nam-ti                namtil[life]
# 2      P432254.conll   4       {d}szul-gi-sze3                _[of.Szulgi]
# 3      P432254.conll   6              x-sa6-ga                    _[-saga]
# 4      P432254.conll   8              nu-kiri6           _[the.orchardman]
# ...              ...  ..                   ...                         ...
# 60198  P458715.conll  10  a-ba-{d}en-lil2-gin7             _[Aba-Enlilgin]
# 60199  P458715.conll  11                  dumu                 dumu[child]
# 60200  P458715.conll  12               id-da-a               Iddaya[1][-e]
# 60201  P458715.conll  13              dam-gar3       damgar[merchant][-ak]
# 60202  P458715.conll  14              ARAD2-zu          arad[slave]-zu[-ø]
#
#                                   xpostag     lem          eng_translation  \
# 0      VEN.3-SG-H.DAT.3-SG-H-A.gin.3-SG-P       _  he_standardized_for_him
# 1                                       N  namtil                     life
# 2                             RN.GEN.TERM       _                of_Szulgi
# 3                                      PN       _                    -saga
# 4                                   N.ERG       _           the_orchardman
# ...                                   ...     ...                      ...
# 60198                                  PN       _             Aba-Enlilgin
# 60199                                   N    dumu                    child
# 60200                              PN.ERG  Iddaya                   Iddaya
# 60201                                   N  damgar                 merchant
# 60202                     N.2-SG-POSS.ABS    arad                    slave
#
#                                   org_tags_split  \
# 0      [VEN, 3-SG-H, DAT, 3-SG-H-A, gin, 3-SG-P]
# 1                                            [N]
# 2                                [RN, GEN, TERM]
# 3                                           [PN]
# 4                                       [N, ERG]
# ...                                          ...
# 60198                                       [PN]
# 60199                                        [N]
# 60200                                  [PN, ERG]
# 60201                                        [N]
# 60202                        [N, 2-SG-POSS, ABS]
#
#                             processed_tags_split
# 0      [ven, 3-sg-h, dat, 3-sg-h-a, gin, 3-sg-p]
# 1                                            [n]
# 2                            [rn, gen, term, np]
# 3                                       [pn, np]
# 4                                       [n, erg]
# ...                                          ...
# 60198                                   [pn, np]
# 60199                                        [n]
# 60200                              [pn, erg, np]
# 60201                                        [n]
# 60202                        [n, 2-sg-poss, abs]
#
# [60203 rows x 9 columns]

# %%
extracted_df.to_csv(r'data/sux_dict_process/sux_dict_vocab_all.txt', index=None, sep=' ', mode='w')

# %% [markdown]
# ## Tag seperation

# %%
all_tags= set()
for i in extracted_df.processed_tags_split:
    for j in i:
        all_tags.add(j)

# %%
all_tags
# Out:
# {'',
#  '1-sg-a',
#  '1-sg-poss',
#  '2-sg-a',
#  '2-sg-poss',
#  '3-nh',
#  '3-nh-poss',
#  '3-pl',
#  '3-pl-dat',
#  '3-pl-s',
#  '3-sg-a',
#  '3-sg-cop',
#  '3-sg-dat',
#  '3-sg-h',
#  '3-sg-h-a',
#  '3-sg-h-dat',
#  '3-sg-h-p',
#  '3-sg-h-poss',
#  '3-sg-hn-p',
#  '3-sg-nh',
#  '3-sg-nh-a',
#  '3-sg-nh-l3',
#  '3-sg-nh-p',
#  '3-sg-nh-poss',
#  '3-sg-p',
#  '3-sg-s',
#  '_',
#  'abl',
#  'abs',
#  'adv',
#  'aj',
#  'an',
#  'ani',
#  'ant',
#  'av',
#  'cnjcoo',
#  'com',
#  'cop',
#  'cop-3-pl',
#  'cop-3-sg',
#  'dah-h',
#  'dat',
#  'dat-h',
#  'dat-nh',
#  'dem2',
#  'det',
#  'dn',
#  'dub[tablet]-ak',
#  'ed',
#  'en',
#  'equ',
#  'erg',
#  'except',
#  'ešnunak',
#  'f',
#  'fin',
#  'fn',
#  'gen',
#  'gen-abl',
#  'gin',
#  'gn',
#  'h',
#  'ip',
#  'l1',
#  'l1-syn',
#  'l2',
#  'l2-nh',
#  'l2-syn',
#  'l3',
#  'l3-nh',
#  'mid',
#  'mid-v11=1-sg-a',
#  'mn',
#  'mod',
#  'mod1',
#  'mod4',
#  'n',
#  'n-rdp',
#  'neg',
#  'nf',
#  'np',
#  'num',
#  'on',
#  'pad',
#  'pf',
#  'pl',
#  'pn',
#  'pt',
#  'rdp',
#  'rn',
#  'sabar',
#  'sn',
#  'stem',
#  'sub',
#  'taramurim',
#  'term',
#  'tn',
#  'vblex',
#  'ven',
#  'wn',
#  'x'}

# %% [markdown]
# ## Creating the dict with most frequent tags and translation

# %%
extracted_df.head()
# Out:
#         filename id             form                         seg  \
# 0  P432211.conll  1      mu-na-gi-in  _[he.standardized.for.him]
# 1  P432254.conll  2           nam-ti                namtil[life]
# 2  P432254.conll  4  {d}szul-gi-sze3                _[of.Szulgi]
# 3  P432254.conll  6         x-sa6-ga                    _[-saga]
# 4  P432254.conll  8         nu-kiri6           _[the.orchardman]
#
#                               xpostag     lem          eng_translation  \
# 0  VEN.3-SG-H.DAT.3-SG-H-A.gin.3-SG-P       _  he_standardized_for_him
# 1                                   N  namtil                     life
# 2                         RN.GEN.TERM       _                of_Szulgi
# 3                                  PN       _                    -saga
# 4                               N.ERG       _           the_orchardman
#
#                               org_tags_split  \
# 0  [VEN, 3-SG-H, DAT, 3-SG-H-A, gin, 3-SG-P]
# 1                                        [N]
# 2                            [RN, GEN, TERM]
# 3                                       [PN]
# 4                                   [N, ERG]
#
#                         processed_tags_split
# 0  [ven, 3-sg-h, dat, 3-sg-h-a, gin, 3-sg-p]
# 1                                        [n]
# 2                        [rn, gen, term, np]
# 3                                   [pn, np]
# 4                                   [n, erg]

# %%
extracted_df.shape
# Out:
# (60203, 9)

# %%
unique_eng_translation = {}
unique_tag_list = {}
for i, row in extracted_df.iterrows():
    # p_tag = sorted(row['processed_tags_split'])
    p_tag = row['processed_tags_split']
    p_tag_str = ".".join(p_tag)
    form = row['form']
    lemma = row['lem']
    dict_key = form+"_SEP_"+lemma
    eng_translation = row['eng_translation']

    # add english translation
    try:
        unique_eng_translation[dict_key].append(eng_translation)
    except:
        unique_eng_translation[dict_key] = [eng_translation]

    # add unique tags
    try:
        unique_tag_list[dict_key].append(p_tag_str)
    except:
        unique_tag_list[dict_key] = [p_tag_str]

# %%
# saving json files
save_json('data/sux_dict_process/unique_eng_translation.json',unique_eng_translation)
save_json('data/sux_dict_process/unique_tag_list.json',unique_tag_list)

# %%
#vocab size
len(unique_tag_list)
# Out:
# 6323

# %%
def val_dict_formation(data_ls):
    d = {}
    for l in data_ls:
        try:
            d[l]+=1
        except:
            d[l] = 1
            
    return sorted(list(d.items()),key=lambda x:x[1], reverse=True)[0][0]

# %%
most_freq_translation = {}
most_freq_tags = {}

for key,val in unique_eng_translation.items():
    most_freq_val = val_dict_formation(val)
    most_freq_translation[key] = most_freq_val


for key,val in unique_tag_list.items():
    most_freq_val = val_dict_formation(val)
    most_freq_tags[key] = most_freq_val

# %%
most_freq_translation
# Out:
# {'mu-na-gi-in_SEP__': 'he_standardized_for_him',
#  'nam-ti_SEP_namtil': 'life',
#  '{d}szul-gi-sze3_SEP__': 'of_Szulgi',
#  'x-sa6-ga_SEP__': '-saga',
#  'nu-kiri6_SEP__': 'the_orchardman',
#  'a_SEP_a': 'water',
#  'mu-na-ru_SEP_mu-nn-a': '-n',
#  'ur-ge6-par4_SEP_Ur-gepar': 'Ur-gepar',
#  'u3-na-a-du11_SEP_u-nn-a-e-dug': 'speak',
#  'gurusz_SEP_gurusz': 'male',
#  '1(u)-am3_SEP_1(u)': 'ten',
#  'ma2_SEP_ma': 'ship',
#  'dug_SEP_dug': 'pot',
#  'ba-al-e-de3_SEP__': 'the_pots_to_unload',
#  'lu2-{d}szara2-ra_SEP__': 'to_Lu-Szara',
#  'he2-na-szum2-mu_SEP__': 'may_he_give',
#  'lu2_SEP_lu': 'person',
#  'us2-gar_SEP__': 'May_with',
#  'he2-eb-da-an-gi4-gi4_SEP__': 'it_return',
#  'lu2-kal-la_SEP_Lukala': 'Lukala',
#  'dub-sar_SEP_dubsar': 'scribe',
#  'dumu_SEP_dumu': 'child',
#  'ur-sa6-ga_SEP_Ursaga': 'Ursaga',
#  '{d}szu-{d}suen_SEP_Szusuen': 'Szusuen',
#  'lugal_SEP_lugal': 'king',
#  'kal-ga_SEP_kalag': 'strong',
#  'uri5{ki}-ma_SEP_Urim': 'Urim',
#  'an_SEP_An': 'An',
#  'ub-da_SEP_': '',
#  'limmu2-ba_SEP_limmu': 'four',
#  'a-ha-am-wa-qar_SEP__': 'Aam-waqar',
#  'ARAD2-zu_SEP_arad': 'slave',
#  'pisan-dub-ba_SEP_bisagdubak': 'filing_basket',
#  'gesztu2-ga_SEP__': 'reports',
#  'ru_SEP__': 'of',
#  'a-zu_SEP__': 'doctors',
#  'i3-gal2_SEP_i': '-ni',
#  'e2-tum_SEP_bitum': 'administrative_term',
#  'ab2_SEP_ab': 'cow',
#  'e2-tur3_SEP_etur': 'stall',
#  'u3_SEP_u': 'and',
#  'gu4-{gesz}apin_SEP_gudapin': 'plow_ox',
#  'mu_SEP_mu': 'year',
#  'gu-za_SEP_guza': 'chair',
#  'ba-dim2_SEP_ba-dim': 'create',
#  '1(disz)_SEP_1(disz)': 'one',
#  'udu-nita2_SEP_udunita': 'ram',
#  'ba-usz2_SEP_ba-usz': 'die',
#  'sila4_SEP_sila': 'lamb',
#  'ASZ-ur4_SEP_azur': 'type_of_sheep',
#  'ki_SEP_ki': 'place',
#  'ur-u3-ta_SEP_Uru': 'Uru',
#  'sza3_SEP_szag': 'heart',
#  'bala-a_SEP_bala': 'tax',
#  'kiszib3_SEP_kiszib': 'seal',
#  'ARAD2_SEP_Arad': 'Arad',
#  'iti_SEP_iti': 'month',
#  'sze-sag11-ku5_SEP_Szesagku': 'Szesagku',
#  'us2-sa_SEP_us': 'follow',
#  'ki-masz{ki}_SEP_Kimasz': 'Kimasz',
#  'ba-hul_SEP_ba-hulu': 'destroy',
#  'ARAD2-mu_SEP_Aradmu': 'Aradmu',
#  'ur-nigar{gar}_SEP_Urnigar': 'Urnigar',
#  'szusz3_SEP_kusz': 'cattle_manager',
#  'udu_SEP_udu': 'sheep',
#  'u8_SEP_u': 'ewe',
#  'masz2-gal_SEP_maszgal': 'billy_goat',
#  'ba-usz2_SEP_ba-ug': 'die',
#  'u4_SEP_ud': 'day',
#  '1(u)_SEP_1(u)': 'ten',
#  'la2_SEP_la': 'hang',
#  '1(disz@t)-kam_SEP_1(disz@t)': 'one',
#  'tum-ma-al_SEP_Tummal': 'Tummal',
#  'en-dingir-mu-ta_SEP_Endingirmu': 'Endingirmu',
#  "{d}szul-gi-iri-mu_SEP_Szulgi'irimu": "Szulgi'irimu",
#  'szu_SEP_szu': 'hand',
#  'ba-ti_SEP_ba': '-n',
#  'a2-ki-ti_SEP_Akiti': 'Akiti',
#  'en_SEP_en': 'priest',
#  '{d}nanna_SEP_Nanna': 'Nanna',
#  'ba-hun_SEP_ba-hug': 'hire',
#  '1/3(disz)_SEP_1/3(disz)': 'one',
#  'gin2_SEP_gig': 'unit',
#  '2(u)_SEP_2(u)': 'ten',
#  'sze_SEP_sze': 'barley',
#  '3(disz)_SEP_3(disz)': 'one',
#  'igi-6(disz)-gal2_SEP_igi6(disz)': 'one',
#  'bi2-tum_SEP_': '',
#  'e2-szu-sum-ma_SEP__': 'xxx',
#  'n_SEP__(_)': '_',
#  'ku3_SEP_kug': 'silver',
#  'masz_SEP_masz': 'interest',
#  'a-sza3-ga_SEP_aszag': 'field',
#  'ur-dun-ta_SEP__': 'Ur-dun',
#  'da-da-ga_SEP_Dadaga': 'Dadaga',
#  'ur-bi2-lum{ki}_SEP_Urbilum': 'Urbilum',
#  'dub-gid2-da_SEP__': 'long-tablets',
#  'lu2-{d}ba-ba6_SEP_Lubaba': 'Lubaba',
#  'ba-lu5_SEP_Balu': 'Balu',
#  'lu2-gu-la_SEP_Lugula': 'Lugula',
#  'ur-{d}igi-zi-bar-ra_SEP_Urigizibarra': 'Urigizibarra',
#  'ha-ar-szi{ki}_SEP_Harszi': 'Harszi',
#  'hu-ur5-ti{ki}_SEP_Hurti': 'Hurti',
#  'ur-ba-gara2_SEP_Urbagara': 'Urbagara',
#  'ur-{d}..._SEP__': '_',
#  'nig2-ka9-ak_SEP_nigSZID': 'account',
#  'a2_SEP_a': 'time',
#  'erin2-na_SEP_erin': 'people',
#  'en-unu6_SEP_': '',
#  '{d}inanna_SEP_Inanna': 'Inanna',
#  'ba-hun-ta_SEP__': 'xxx',
#  'sza-asz-ru-um{ki}-sze3_SEP__': 'xxx',
#  'szuku-ra_SEP_szukur': 'ration',
#  'ak_SEP_ak': 'excavate',
#  'dam-gar3_SEP_damgar': 'merchant',
#  'gar-ra-ke4-ne_SEP__': 'xxx',
#  'masz-e_SEP_masz': 'goat',
#  'i3-pa3_SEP_i-pad': 'find',
#  'gurum2_SEP_gurum': 'inspection',
#  'sag-apin_SEP__': 'xxx',
#  'e2_SEP_e': 'house',
#  '{d}en-lil2_SEP_Enlil': 'Enlil',
#  '{d}en-ki_SEP_Enki': 'Enki',
#  '{d}nin-gul_SEP__': 'xxx',
#  '{d}dumu-zi_SEP_Dumuzi': 'Dumuzi',
#  'nam-ha-ni_SEP_Namhani': 'Namhani',
#  '{d}nin-dar-a_SEP__': 'xxx',
#  '5(u)_SEP_5(u)': 'ten',
#  '5(asz)_SEP_5(asz)': 'one',
#  '2(barig)_SEP_2(bariga)': 'unit',
#  'gur_SEP_gur': 'unit',
#  '1/2(disz)_SEP_1/2(disz)': 'one',
#  'ma-na_SEP_mana': 'unit',
#  '8(disz)_SEP_8(disz)': 'one',
#  '2/3(disz)_SEP_2/3(disz)': 'one',
#  '5(disz)_SEP_5(disz)': 'one',
#  'ku3-babbar_SEP_kugbabbar': 'silver',
#  'mu-kux(DU)_SEP_mukur': 'delivery',
#  'ad-da-kal-la_SEP_Addakala': 'Addakala',
#  '1(disz)-sze3_SEP_1(disz)': 'one',
#  'tir_SEP_tir': 'forester',
#  'szum2-bad3-x_SEP__': 'forest_Szum-bad-',
#  '{gesz}u2-bil2-x_SEP__': 'charcoal',
#  'ga-ma-la_SEP__': 'Gamala',
#  'ugula_SEP_ugula': 'overseer',
#  'ur-am3-ma_SEP_Uramma': 'Uramma',
#  'lugal-nir_SEP_Lugalnir': 'Lugalnir',
#  'ezem-{d}szul-gi_SEP_Ezemszulgir': 'Ezemszulgir',
#  'na-ru2-a_SEP_narua': 'stele',
#  'ba-du3_SEP_ba-du': 'build',
#  'ur-{d}szara2_SEP_Urszara': 'Urszara',
#  'sza13-dub-ba-ka_SEP_bisagdubak': 'archivist',
#  'niga_SEP_niga': 'fattened',
#  'gukkal_SEP_gukkal': 'fat-tailed_sheep',
#  '2(disz)_SEP_2(disz)': 'one',
#  '{munus}asz2-gar3_SEP_aszgar': 'female_kid',
#  'a-bi2-si2-im-ti_SEP_Abisimti': 'Abisimti',
#  'u4-sakar_SEP_usakar': 'crescent_moon',
#  'ri-zi-dingir_SEP__': 'Rizi-ilum',
#  'maszkim_SEP_maszkim': 'administrator',
#  'lugal-ma2!-gur8-re_SEP_Lugalmagure': 'Lugalmagure',
#  '..._SEP__': '_',
#  '{d}nin-lil2_SEP_Ninlil': 'Ninlil',
#  '{d}nin-urta_SEP_Ninurta': 'Ninurta',
#  '...-zi_SEP_': '',
#  'mu-kux(DU)-ra-ta_SEP__': 'from_deliveries',
#  '6(disz)-kam_SEP_6(disz)': 'one',
#  'ab-ba-sa6-ga-ta_SEP_Abbasaga': 'Abbasaga',
#  'ba-zi_SEP_ba-zig': 'expend',
#  'ezem-mah_SEP_Ezemmah': 'Ezemmah',
#  'en-unu6-gal_SEP_Enunugal': 'Enunugal',
#  '1(ban2)_SEP_1(ban)': 'unit',
#  'sila3_SEP_sila': 'unit',
#  'i3-nun_SEP_inun': 'ghee',
#  '6(disz)_SEP_6(disz)': 'one',
#  'ga_SEP_ga': 'milk',
#  'gazi_SEP_gazi': 'condiment',
#  'ur-mes-ta_SEP_Urmes': 'Urmes',
#  'ur-{d}dumu-zi_SEP_Urdumuzi': 'Urdumuzi',
#  'szu-gar-gal_SEP_Szugargal': 'Szugargal',
#  "5(gesz'u)_SEP_5(gesz'u)": 'six_hundred',
#  '9(gesz2)_SEP_9(gesz)': 'sixty',
#  '5/6(asz)_SEP_': '',
#  'gu2_SEP_gun': 'unit',
#  'gi-zi_SEP_gizi': 'reed',
#  'puzur4-isz-{d}da-gan_SEP_Puzuriszdagan': 'Puzuriszdagan',
#  "2(gesz'u)_SEP_2(gesz'u)": 'six_hundred',
#  '3(gesz2)_SEP_3(gesz)': 'sixty',
#  '4(u)_SEP_4(u)': 'ten',
#  '6(asz)_SEP_6(asz)': 'one',
#  'nibru{ki}_SEP_Nibru': 'Nibru',
#  '1(szar2)_SEP_1(szar)': 'unit',
#  '1(asz)_SEP_1(asz)': 'one',
#  'sza3-gal_SEP_szaggal': 'food',
#  'niga-sze3_SEP__': 'grain-fed',
#  'erin2_SEP_erin': 'people',
#  'gir2-su{ki}_SEP_Girsu': 'Girsu',
#  'sukkal-mah_SEP__': 'sukkalma',
#  '{d}szul-gi-i3-li2_SEP_Szulgirili': 'Szulgirili',
#  'giri3_SEP_giri': 'foot',
#  'lu2-giri17-zal_SEP_Lugirizal': 'Lugirizal',
#  'masz-da3-gu7_SEP_Maszdagu': 'Maszdagu',
#  '{d}i-bi2-{d}suen_SEP_Ibbisuen': 'Ibbisuen',
#  '7(disz)_SEP_7(disz)': 'one',
#  'masz2_SEP_masz': 'goat',
#  'ud5_SEP_uzud': 'goat',
#  'e2-muhaldim_SEP_emuhaldim': 'kitchen',
#  '5(disz)-kam_SEP_5(disz)': 'one',
#  'zi-ga_SEP_zig': 'expend',
#  'ur-ku3-nun-na_SEP_Urkununa': 'Urkununa',
#  'ki-masz2_SEP_': '',
#  'di_SEP_did': 'lawsuit',
#  'til-la_SEP_til': 'complete',
#  'puzur4-isz-da-gan_SEP__': 'xxx',
#  'kasz_SEP_kasz': 'beer',
#  'saga_SEP_saga': 'good',
#  'ninda_SEP_ninda': 'bread',
#  'i3_SEP_i': 'oil',
#  'naga_SEP_naga': 'potash',
#  'ku6_SEP_kud': 'fish',
#  'sa_SEP_sa': 'bundle',
#  'szum2_SEP_szum': 'garlic',
#  'lu2-{d}nanna_SEP_Lunanna': 'Lunanna',
#  'ur-{d}nanna_SEP__': 'Ur-Nanna',
#  '3(ban2)_SEP_3(ban)': 'unit',
#  'du_SEP_gin': 'quality_designation',
#  'i3-gesz_SEP_igesz': 'oil',
#  'kas4-e-ne_SEP__': 'provisions_messengers',
#  '1(disz)-kam_SEP_1(disz)': 'one',
#  'sig4-{gesz}i3-szub-ba-gar_SEP_Sigiszubbagar': 'Sigiszubbagar',
#  '4(disz)-sze3_SEP_4(disz)': 'one',
#  'kar_SEP__': 'from',
#  'umma{ki}-ta_SEP_Umma': 'Umma',
#  'iri-sa12-rigx(|PA.MUNUS.HUB2.DU|){ki}-sze3_SEP__': 'to_Irisagrig',
#  'gid2-da_SEP_gid': 'lengthen',
#  'ma2-a_SEP_ma': 'ship',
#  'si-ga_SEP_sig': 'load',
#  'iri-sa12-rigx(|PA.MUNUS.HUB2.DU|){ki}-ta_SEP__': 'from_Irisagrig',
#  '2(disz)-sze3_SEP_2(disz)': 'one',
#  'kun-zi-da_SEP_kunzida': 'weir',
#  '{gesz}kiri6_SEP_kiri': 'orchard',
#  'gesztin-sze3_SEP__': 'Vineyard',
#  'diri-ga_SEP_dirig': 'drift',
#  '8(disz)-sze3_SEP_8(disz)': 'one',
#  'e2-duru5_SEP_eduru': 'village',
#  'uri3-ru2-a-ta_SEP__': 'Uriru-village',
#  'i7_SEP_id': 'river',
#  '{d}amar-{d}suen-ni-tum-sze3_SEP__': 'Amar-Suentum_canal',
#  'ga6-ga2_SEP_gag': 'carry',
#  '{d}amar-{d}suen-ni-tum-ma-ta_SEP__': 'from_reservoir_Amar-Suentum_canal',
#  'bala_SEP_bala': 'turn',
#  'ka_SEP_kag': 'mouth',
#  'da-mi-ma-ma-sze3_SEP__': 'mouth_Damimama',
#  'umma{ki}-sze3_SEP__': 'to_Umma',
#  'ba-al-la_SEP_bala': 'transfer',
#  "i7-pa-e3_SEP_Ipa'e": "Ipa'e",
#  'a-du-mu_SEP_Adumu': 'Adumu',
#  'ba-ab-du8_SEP_ba-b-du': 'caulk',
#  'ur-{d}suen_SEP_Ursuen': 'Ursuen',
#  'ur-{gesz}gigir_SEP_Urgigir': 'Urgigir',
#  'sza3-tam_SEP__': 'official',
#  'sze-ba_SEP_szeba': 'ration',
#  'giri3-se3-ga_SEP_girsiga': 'attendant',
#  'ugnim{ki}_SEP__': 'Ugnim',
#  'an-na-hi-li-bi-ta_SEP_Annahilibi': 'Annahilibi',
#  "pa4-u2-e_SEP_Pa'u'e": "Pa'u'e",
#  "ur-e11-e_SEP_Ure'e": "Ure'e",
#  'usz2_SEP_usz': 'dead',
#  'ur-sila-luh_SEP__': 'Ur-silaluh',
#  '1(asz@c)_SEP_1(asz)': 'one',
#  'GAN2_SEP_gana': 'field',
#  "e2-ur2-bi-du10_SEP_E'urbidu": "E'urbidu",
#  "giri3-ni-i3-sa6_SEP_Girini'isa": "Girini'isa",
#  'dumu-ni-me_SEP_dumu': 'son',
#  'ur-{d}gesztin-an-ka_SEP_Urgesztinanka': 'Urgesztinanka',
#  'lu2-{d}sukkal-an-ka_SEP_Lusukkalankak': 'Lusukkalankak',
#  'ki-sur-ra_SEP__': 'in_borderland',
#  'i3-dab5_SEP_i': '-n',
#  '1(barig)_SEP_1(bariga)': 'unit',
#  '4(disz)_SEP_4(disz)': 'one',
#  'ug3_SEP_ug': 'people',
#  'du11-ga-ni_SEP_Dugani': 'Dugani',
#  'szu-na-mu-gi4_SEP__': 'Szunamugi-woods_took_in',
#  'inim-{d}szara2_SEP_Inimszara': 'Inimszara',
#  'lugal-inim-gi-na_SEP_Lugalinimgina': 'Lugalinimgina',
#  'dumu-ni_SEP_dumu': 'child',
#  'a-kun-kum2_SEP__': 'Akunkum-woods_took_in',
#  'ur-ab-ba_SEP_Urabba': 'Urabba',
#  'lu2-{d}szara2_SEP_Luszara': 'Luszara',
#  'ka-ma-ri2{ki}_SEP_Kamari': 'Kamari',
#  'lugal-iti-da_SEP_Lugalitida': 'Lugalitida',
#  'lu2-gi-na_SEP_Lugina': 'Lugina',
#  'a-hu-ba-qar_SEP__': 'a-_Au-baqar',
#  'a-ta2-na-ah_SEP__': 'di-_Atanna',
#  'a-sza3_SEP_aszag': 'field',
#  'am3-ri2_SEP__': 'Amri-field-woods_took_in',
#  "lu2-{d}ab-u2_SEP_Lu'abu": "Lu'abu",
#  "lu2-eb-gal_SEP_Lu'ebgal": "Lu'ebgal",
#  'lu2-{d}en-ki-du_SEP__': 'Lu-Enkidu',
#  'da-a-da-ga_SEP__': '-sons_Dayadaga-',
#  'u2-la2{ki}_SEP__': 'Ula-woods_took_in',
#  'a-du-du_SEP_Adudu': 'Adudu',
#  'lugal-ku3-zu_SEP_Lugalkuzu': 'Lugalkuzu',
#  '{gesz}kiri6-mah_SEP__': 'Big-orchard-woods_took_in',
#  'nu_SEP_nu': 'not',
#  'inim-ma-ni-zi_SEP_Inimanizi': 'Inimanizi',
#  'ur-e2-mah_SEP_Uremah': 'Uremah',
#  '{d}utu-saga_SEP__': 'Utu-saga',
#  'ur-{d}ur3-bar-tab_SEP__': 'Ur-Urbartab',
#  'dul4-la_SEP__': 'Dula-waterway-woods_took_in',
#  'sza3-gu2-bi_SEP_Szagubi': 'Szagubi',
#  'zah3_SEP_zah': 'disappear',
#  '{d}szara2-si_SEP__': 'Szarasi-field-woods_took_in',
#  'ur-e2-masz_SEP_Uremasz': 'Uremasz',
#  'da-gu-na_SEP__': 'Daguna-woods_took_in',
#  'szesz-kal-la_SEP_Szeszkala': 'Szeszkala',
#  'lugal-hi-li_SEP_Lugalhili': 'Lugalhili',
#  '{d}szara2-zi-da_SEP__': 'a-_Szara-zida',
#  'al-lu-me_SEP__': '-they_are_sons_Allu-',
#  'e2-lugal_SEP__': 'Royal-house-woods_took_in',
#  'a-kal-la_SEP_Akala': 'Akala',
#  'ur-tul2-mah_SEP_Urtulmah': 'Urtulmah',
#  'kar-ra_SEP__': 'Quay-woods_took_in',
#  'lugal-he2-gal2_SEP_Lugalhegal': 'Lugalhegal',
#  'ma-sar_SEP__': 'Masar-woods_took_in',
#  'lu2-dingir-ra_SEP_Ludingira': 'Ludingira',
#  'ur-lugal_SEP_Urlugal': 'Urlugal',
#  'tu-ru-da_SEP__': 'Turuda-woods_took_in',
#  'ur-gu_SEP_Urgu': 'Urgu',
#  'lu2-{d}nin-a-zu_SEP__': 'di-_Lu-Ninazu',
#  'nag-su{ki}_SEP__': 'Nagsu-woods_took_in',
#  'lugal-za3-ge_SEP_Lugalzage': 'Lugalzage',
#  'gir13-gesz{ki}_SEP__': 'Girge-woods_took_in',
#  'a2-ta_SEP_Ata': 'Ata',
#  'inim-e3_SEP__': 'Inime-woods_took_in',
#  'ab-ba-saga_SEP_Abbasaga': 'Abbasaga',
#  'bala-a-ti-im-durunx(|KU.KU|)_SEP__': 'Balaatimdurun-woods_took_in',
#  '{d}szara2-kam_SEP_Szarakam': 'Szarakam',
#  'adab{ki}_SEP__': 'Adab',
#  'ba-an-sa6_SEP_Bayansa': 'Bayansa',
#  'ur-sukkal_SEP__': 'di-_Ur-sukkal',
#  'zabala3{ki}_SEP__': 'Zabala-woods_took_in',
#  'gal-la_SEP__': 'Big-waterway-woods_took_in',
#  'ARAD2_SEP_arad': 'slave',
#  'lu2-he2-gal2_SEP_Luhegal': 'Luhegal',
#  'ha-la-{d}ma-mi_SEP__': 'a-_ala-Mami',
#  'lugal-nesag-e_SEP_Lugalnesage': 'Lugalnesage',
#  'gar-sza-na-ka{ki}_SEP__': 'Garana-woods_took_in',
#  "i-di3-a_SEP_Idi'a": "Idi'a",
#  'erin2-gar-sza-na-ka{ki}_SEP__': 'troops-of-Garana-woods_took_in',
#  'lu2-ga_SEP_Luga': 'Luga',
#  'ur-{d}dumu-zi-da_SEP_Urdumuzida': 'Urdumuzida',
#  'ur-mes_SEP_Urmes': 'Urmes',
#  'sza3-nin9-ti-na_SEP__': 'Midst-of-Nintina-woods_took_in',
#  'sza3-ku3-sig17_SEP__': 'a-c-_Szakusig',
#  'gaba-ri-gar-sza-na-ka_SEP__': 'Copy-of-Garana-woods_took_in',
#  'ma2-szuku-diri_SEP__': 'Extra-prebend-boat-woods_bank_Namani-waterway_took_in',
#  'ARAD2-{d}szara2_SEP_Aradszara': 'Aradszara',
#  'ha-an-da_SEP__': 'anda',
#  'nu-{gesz}kiri6_SEP__': 'orchardman',
#  'uku2-nu-ti_SEP_': '',
#  '{d}szul-gi-he2-gal2_SEP__': 'Ukunuti-woods_bank_Szulgi-egal-waterway_took_in',
#  'ab-ba-gi-na_SEP_Abbagina': 'Abbagina',
#  'da-a-a_SEP__': 'a-c-_Dayya',
#  'im-e_SEP__': 'remainder',
#  'tak4-a_SEP_taka': 'abandon',
#  'iri-bu3-ra_SEP__': 'Bura-town-woods_took_in',
#  'lal3-mes_SEP_Lalmes': 'Lalmes',
#  'a-du10-ga-nigin_SEP__': 'Aduganigin-woods_took_in',
#  'a-bu-du10_SEP__': 'a-c-_Abu-tab',
#  'gar-su4-da_SEP__': 'Garsuda-woods_took_in',
#  'lugal-da-ga_SEP__': 'a-c-_Lugal-daga',
#  'ama-ki_SEP__': 'Ama-ki_oldest',
#  'pa4_SEP__': 'brother',
#  'ur-{d}isztaran_SEP_Urisztaran': 'Urisztaran',
#  'GAN2-masz{ki}_SEP__': 'GANma-woods_took_in',
#  'szunigin_SEP_szunigin': 'total',
#  '3(asz@c)_SEP_3(asz)': 'one',
#  'dumu-nita2_SEP__': 'di-_male_children',
#  'diri_SEP_diri': 'intercalary_month',
#  'szu-gi4_SEP__': 'old',
#  '2(u@c)_SEP_2(u)': 'ten',
#  'nu-dab_SEP__': 'a-c-_corporate_slave_not_took_in_charge',
#  '4(asz@c)_SEP_4(asz)': 'one',
#  'siki-ta_SEP__': 'wool_each_a-_corporate_slave_at',
#  'ug3-IL2-me_SEP__': '-they_are_porters-',
#  'sze-bi_SEP_sze': 'barley',
#  'iti-da_SEP_itud': 'worker_category',
#  'be6-dam_SEP__': 'to_be_distributed_monthly',
#  'siki-bi_SEP_siki': 'wool',
#  'mu-a_SEP_': '',
#  'dab-ba_SEP_dab': 'seize',
#  'tir-ra_SEP__': 'passed_by_as_foresters',
#  'a-a-kal-la_SEP_Ayakala': 'Ayakala',
#  'ensi2_SEP_ensik': 'ruler',
#  'umma{ki}_SEP_Umma': 'Umma',
#  'sza3-ta-ku3-zu_SEP_Szatakuzu': 'Szatakuzu',
#  'sukkal_SEP_sukkal': 'secretary',
#  "lu2-{d}inanna_SEP_Lu'inanna": "Lu'inanna",
#  'ezem-{d}dumu-zi_SEP_Ezemdumuzi': 'Ezemdumuzi',
#  'en-nun-ne2-{d}amar-{d}suen-ra-ki-ag2_SEP__': 'Ennune-Amar-Suenra-kiag_as',
#  'eridu{ki}_SEP_Eridug': 'Eridug',
#  'igi-pesz2_SEP__': 'Ratface',
#  'ur-{d}iszkur_SEP_Uriszkur': 'Uriszkur',
#  "1(gesz'u)_SEP_1(gesz'u)": 'six_hundred',
#  'pa-ku5_SEP_pakud': 'stave',
#  'gu-nigin2-ba_SEP_gunigin': 'bale',
#  'sa-ta_SEP_sa': 'bundle',
#  '{gesz}dal_SEP_dal': 'crossbar',
#  '5(gesz2)_SEP_5(gesz)': 'sixty',
#  'ma-nu_SEP_manu': 'wood_type',
#  'nig2-ba_SEP_nigba': 'gift',
#  'sig4-te-la2-ni_SEP_Sigtelani': 'Sigtelani',
#  'szu-ma-ma_SEP_Szumama': 'Szumama',
#  'kin-gi4-a_SEP_kiggia': 'messenger',
#  'lu2-tur-tur_SEP_Luturtur': 'Luturtur',
#  '3(u)_SEP_3(u)': 'ten',
#  'ur-{d}nin-lil2-la2_SEP_Urninlila': 'Urninlila',
#  'ka(SAG)-guru7_SEP_kaguruk': 'granary_supervisor',
#  'ur-sila-luh-ta_SEP_Ursilaluh': 'Ursilaluh',
#  'ensi2-ka_SEP_ensik': 'ruler',
#  '{d}amar-{d}suen_SEP_Amarsuen': 'Amarsuen',
#  '{d}szul-gi_SEP_Szulgir': 'Szulgir',
#  'nita_SEP_nita': 'male',
#  'an-ub-da_SEP_anubda': 'quarter',
#  'ur-{d}li9-si4_SEP_Urlisi': 'Urlisi',
#  'gu-za-la2-e-ne_SEP__': 'xxx',
#  'uri5{ki}-ma-ke4_SEP_Urim': 'Urim',
#  'ma-da_SEP_mada': 'land',
#  'za-ab-sza-li{ki}_SEP_Zabszali': 'Zabszali',
#  'mu-hul_SEP_mu': '-n',
#  '(x)_SEP__': '_',
#  'an-na-he-gal2_SEP__': 'Ana-egal',
#  'ma2-gur8-re_SEP_Magure': 'Magure',
#  'gu4_SEP_gud': 'ox',
#  '{d}nin-gir2-su_SEP_Ningirsu': 'Ningirsu',
#  '{d}ig-alim_SEP__': 'xxx',
#  'uri5{ki}-ma!_SEP_Urim': 'Urim',
#  'ur-{d}utu!_SEP_Urutu': 'Urutu',
#  'ARAD2-da-ne2_SEP__': 'his_servant',
#  '9(asz)_SEP_9(asz)': 'one',
#  'gin2-a_SEP__': 'in_shekel',
#  'ku3-bi_SEP_kug': 'silver',
#  '9(disz)_SEP_9(disz)': 'one',
#  'lugal-pirig-banda3-ta_SEP__': 'Lugal-pirigbanda',
#  'sag-nig2-gur11-ra-kam_SEP_sagnigGArak': 'available_assets',
#  'sza3-bi-ta_SEP_szag': 'heart',
#  '3(asz)_SEP_3(asz)': 'one',
#  'esir2_SEP_esir': 'bitumen',
#  'E2-A_SEP_Ea': 'Ea',
#  'lugal-ta_SEP_lugal': 'king',
#  '4(barig)_SEP_4(bariga)': 'unit',
#  '2(ban2)_SEP_2(ban)': 'unit',
#  '3(ban2)-ta_SEP_3(ban)': 'unit',
#  '1/3(disz){sza}_SEP_1/3(disz)': 'one',
#  'za-ha-din_SEP__': 'barig_leeks',
#  'sila3-ta_SEP_sila': 'unit',
#  'szum2-sikil_SEP__': 'garlic_at',
#  '4(ban2)-ta_SEP__': 'ban_each',
#  '3(barig)_SEP_3(bariga)': 'unit',
#  '4(ban2)_SEP_4(ban)': 'unit',
#  'gaz_SEP_gaz': 'type_of_garlic',
#  'igi-4(disz)-gal2_SEP_igi4(disz)': 'one',
#  '4(asz)_SEP_4(asz)': 'one',
#  'gur-ta_SEP_gur': 'unit',
#  'igi-3(disz)-gal2_SEP_': '',
#  'mun_SEP_mun': 'salt',
#  '2/3(|NINDA2x(SZE.2(ASZ))|)_SEP_': '',
#  '{gesz}u3-suh5_SEP_usuh': 'tree',
#  'gesz_SEP_gesz': 'tree',
#  'e2-szum-ta!_SEP__': 'lumber_from_slaughterhouse',
#  'igi-3(disz)-gal2_SEP__': 'shekel',
#  '{gesz}pesz3_SEP_pesz': 'fig',
#  'duru5_SEP__': 'wet',
#  'zu2-lum_SEP_zulum': 'date',
#  'had2_SEP_had': 'pure',
#  'gu2-ta_SEP__': 'at_talents_each',
#  "la2-ia3_SEP_la'u": 'arrears',
#  "ur-{d}szul-pa-e3_SEP_Urszulpa'e": "Urszulpa'e",
#  'ezem-sze-il2-la_SEP__': 'Festival-grain-lifted_and',
#  'GAN2-masz_SEP_GANmasz': 'GANmasz',
#  '2(disz)-kam_SEP_2(disz)': 'one',
#  'bala-bi_SEP__': 'the_bala_involved',
#  '1(disz)-am3_SEP_': '',
#  'ur-{d}lamma_SEP_Urlamma': 'Urlamma',
#  'si-mu-ru-um{ki}_SEP_Simurrum': 'Simurrum',
#  'lu-lu-bu-um{ki}_SEP_Lulubum': 'Lulubum',
#  'a-ra2_SEP_ara': 'times',
#  '9(disz)-kam-asz_SEP_': '',
#  "la2-ia3-ta_SEP_la'u": 'arrears',
#  'su-ga_SEP_sug': 'repay',
#  'ISZ-su{ki}_SEP_Iszsu': 'Iszsu',
#  "lu2-sa6-i3-zu-ta_SEP_Lusa'izu": "Lusa'izu",
#  '...-x-ni_SEP__': '_',
#  'dal_SEP_Dal': 'Dal',
#  'bad3_SEP_bad': 'wall',
#  'ur-{d}nansze_SEP_Urnansze': 'Urnansze',
#  'dab5_SEP_': '',
#  'lu2-{d}na-ru2-a-ka-ra_SEP__': 'Ur-Nansze_DAB-worker_Lu-Narua',
#  'esz2-giri17-sze3_SEP__': 'the_nose-rope',
#  'na-ba-du3_SEP_nan-ba': '-e',
#  'lugal-ezem_SEP_Lugalezem': 'Lugalezem',
#  'ur-kun_SEP_Urkun': 'Urkun',
#  'nin-a-ni-ir_SEP__': 'his_mistress',
#  'a-tu_SEP_Atu': 'Atu',
#  'nigar{gar}-ki-du10_SEP_Nigarkidu': 'Nigarkidu',
#  'gal5-la2-gal_SEP__': 'The_police_chief',
#  'gesz-gi_SEP__': 'xxx',
#  'mar-sa_SEP_marsa': 'shipyard',
#  'e2-uzu_SEP__': 'xxx',
#  'ezem-{d}szul-gi-ta_SEP_Ezemszulgir': 'Ezemszulgir',
#  '{d}nin-gal-e2-nun-na_SEP__': 'for_Ningal-enuna',
#  'a-ru-a_SEP__': 'offerings',
#  'lu2-dingir-ra-ta_SEP_Ludingira': 'Ludingira',
#  'bi2-tum-ra-bi2-um_SEP__': 'Bitum-rabium_Iabru',
#  'i3-ab-ru{ki}_SEP__': 'its',
#  'ma-da{ki}-bi_SEP__': 'territories',
#  'hu-uh2-nu-ri{ki}_SEP_Huhnuri': 'Huhnuri',
#  "szu-{d}iszkur_SEP_Szu'iszkur": "Szu'iszkur",
#  '5(ban2)_SEP_5(ban)': 'unit',
#  '4(disz)-kam_SEP_4(disz)': 'one',
#  'nesag_SEP_Nesag': 'Nesag',
#  '<us2>-sa_SEP_us': 'follow',
#  'sza-asz-ru-um{ki}_SEP_Szaszrum': 'Szaszrum',
#  "geme2-{d}ig-alim_SEP_Geme'igalim": "Geme'igalim",
#  'nam-mah_SEP_Nammah': 'Nammah',
#  'SIG7-a-ra_SEP_Sigara': 'Sigara',
#  'mar-tu_SEP_Martu': 'Martu',
#  'lu2-nigin6{ki}-ke4_SEP_Lunigin': 'Lunigin',
#  'inim_SEP_inim': 'word',
#  'in-ni-gar-ra_SEP_i-nn-i-n-gar': 'claim',
#  'geme2-mu_SEP_geme': 'female_worker',
#  'ni_SEP_ni': 'self',
#  'i3-me-a_SEP_i-me': 'be',
#  'i3-bi2-za-asz_SEP_ibiza': 'financial_loss',
#  'e2-gal-e_SEP_egal': 'palace',
#  'ma-ab-szum2-ma_SEP_mu-a-b-szum': 'give',
#  "gu3-de2-a_SEP_Gude'a": "Gude'a",
#  "ab-ba-iri_SEP_abba'iri": 'city_elder',
#  'lu2-gir2-su{ki}_SEP_Lugirsu': 'Lugirsu',
#  'ur-x-da_SEP__': '_',
#  'kas4_SEP_kas': 'runner',
#  'maszkim-bi-me_SEP_maszkim': 'administrator',
#  'bi2-in-du11_SEP_b-i-n-dug': 'speak',
#  'en3_SEP_en': 'word',
#  'ba-ne-tar-ra_SEP_ba-nne-tar': 'ask',
#  'inim-bi_SEP_inim': 'matter',
#  'nu-u3-zu_SEP_nu-i': '-n',
#  'bi2-in-ne2-sza-sze3_SEP_bi-i-n-e': 'speak',
#  'geme2_SEP_geme': 'female_worker',
#  'lu2-gu2-gal_SEP_Lugugal': 'Lugugal',
#  'lu2-{d}ba-ba6-ka_SEP_Lubaba': 'Lubaba',
#  'ba-na-gi-in_SEP_ba-nn-a-gin': 'comfirm',
#  'erin-da_SEP_Erinda': 'Erinda',
#  'ur-{d}isztaran_SEP_Uristaran': 'Uristaran',
#  'di-ku5-bi-me_SEP_dikud': 'judge',
#  'szagina_SEP_szakkanak': 'governor',
#  'x_SEP__': '_',
#  'mar-za_SEP_marza': 'rites',
#  'ki-ba_SEP_ki': 'place',
#  'tusz-sza-me_SEP_tusz': 'sit',
#  '1(gesz2)_SEP_1(gesz)': 'sixty',
#  'a2-bi_SEP_a': 'labor',
#  '8(szar2)_SEP_8(szar)': 'thirty-six_hundred',
#  'tug2_SEP_tug': 'textile',
#  'nig2-lam2_SEP_niglam': 'ceremonial_garment',
#  '3(disz)-kam_SEP_3(disz)': 'one',
#  'us2_SEP_us': 'follow',
#  'geme2-bi_SEP_geme': 'female_worker',
#  '1/3(disz)-am3_SEP_1/3(disz)': 'one',
#  'guz-za_SEP_guza': 'chair',
#  'sag_SEP_sag': 'head',
#  'usz-bar_SEP_uszbar': 'weaver',
#  '5/6(disz)-am3_SEP_5/6(disz)': 'one',
#  'gada_SEP_gada': 'flax',
#  '{gesz}tag_SEP_szerim': 'part_of_loom',
#  'du3-a_SEP_du': 'build',
#  'ensi2-ta_SEP_ensik': 'ruler',
#  'hi-a_SEP_hi': 'mix',
#  '2(u)-am3_SEP_2(u)': 'ten',
#  'kir11_SEP_kir': 'female_lamb',
#  'u3-tu-da_SEP__': 'newborns',
#  'na-gab2-tum_SEP_nakabtum': 'stockyard',
#  '{d}szul-gi-a-a-mu_SEP_Szulgirayamu': 'Szulgirayamu',
#  'min3-kam_SEP__': 'Festival_second',
#  'tag-tag-ga_SEP__': 'weaving',
#  'udu-gi_SEP__': 'domestic_sheep',
#  'szul-gi_SEP_Szulgir': 'Szulgir',
#  "ki-en-gi_SEP_ki'engi": "ki'engi",
#  'ki-uri-ke4_SEP__': 'and_and_Akkad',
#  'hur-sag_SEP__': 'mouflon',
#  'ki-ag2-ga2-ni_SEP__': 'his_beloved',
#  'mu-du3_SEP_mu': '-n',
#  'gurum2-ak_SEP_gurum': 'inspection',
#  'gu4-apin_SEP__': 'plow-oxen',
#  'gub-ba_SEP_gub': 'assigned',
#  'gesz-e3-a_SEP__': 'threshed',
#  'szu-du8-a_SEP_': '',
#  '{d}nin-{d}su4-an-na_SEP__': 'Ninsiana',
#  'dab5-ba_SEP_dab': 'seize',
#  'x{ki}_SEP__': '_',
#  'a-de2_SEP__': 'irrigation',
#  'gu4-sze3_SEP__': 'for_oxen',
#  'ha-la_SEP_Hala': 'Hala',
#  "ma2-dara3-abzu_SEP_Madara'abzu": "Madara'abzu",
#  'in-dim2_SEP__': 'Ma-dara-apsu_fashioned',
#  '{u2}gamun2_SEP__': 'cumin',
#  'ge6_SEP_giggi': 'black',
#  'gur-dub-bi_SEP__': 'its_gurdub',
#  '4(disz)-am3_SEP_4(disz)': 'one',
#  "siki-ud5_SEP_siki'ud": 'goat_wool',
#  'gur-bi_SEP__': 'its_gur',
#  'sze-lu2_SEP__': 'barig_coriander',
#  'dug-3(ban2)-bi_SEP__': 'its_vessels',
#  '2(disz)-am3_SEP_2(disz)': 'one',
#  'dug-bi_SEP__': 'its_vessels',
#  '2(gesz2)_SEP_2(gesz)': 'sixty',
#  '3(disz)!_SEP_3(disz)': 'one',
#  '{kusz}ummu3_SEP_ummud': 'waterskin',
#  '5(disz)-am3_SEP_5(disz)': 'one',
#  'szabra-a_SEP__': 'household_manager',
#  'i3-szah2_SEP_iszah': 'lard',
#  '4(disz)-ba_SEP_': '',
#  'bu-zu-a-ta_SEP__': 'Buzua',
#  'e2-kiszib3-ba-ka_SEP__': 'brought',
#  'ba-an-kux(KWU147)_SEP__': 'palace_brought',
#  'kar-gesztin-ka_SEP__': 'Kar-getin',
#  '2(esze3)_SEP_2(esze)': 'unit',
#  'lugal-nig2-lagar-e_SEP_Lugalniglagare': 'Lugalniglagare',
#  'gudu4_SEP_gudug': 'priest',
#  '1/4(iku)_SEP_1/4(iku)': 'unit',
#  'dam_SEP_dam': 'spouse',
#  '1(bur3)_SEP_1(bur)': 'unit',
#  'ur-li-mu_SEP__': 'iku_field_area_barig_ban_Ur-limu',
#  '8(asz)_SEP_8(asz)': 'one',
#  'n(esze3)_SEP__(esze)': 'unit',
#  '3(iku)_SEP_3(iku)': 'unit',
#  '4(iku)_SEP_4(iku)': 'unit',
#  '1(esze3)_SEP_1(esze)': 'unit',
#  '1(iku)_SEP_1(iku)': 'unit',
#  'er3-mu_SEP__': 'ban_Ermu',
#  '2(iku)_SEP_2(iku)': 'unit',
#  '5(barig)_SEP_': '',
#  'gurx(|SZE.KIN|)_SEP__': 'barig_harvested',
#  'x-gibil_SEP__': 'at_-new',
#  '5(iku)_SEP_5(iku)': 'unit',
#  '1/2(iku)_SEP_1/2(iku)': 'unit',
#  'da-a-ga_SEP_': '',
#  '2(asz)_SEP_2(asz)': 'one',
#  'lu2-du10-ga_SEP_Luduga': 'Luduga',
#  'igi-husz_SEP__': 'ee_field_area_barig_Igihu',
#  'in-zu-a_SEP__': 'Inzua',
#  'igi-sze3_SEP_igi': 'eye',
#  'ha-ba-lu5-ge2_SEP_Habaluge': 'Habaluge',
#  'gaba_SEP_gaba': 'frontier',
#  'x-x-dingir_SEP__': 'up_against',
#  'apin-la2-am3_SEP__': 'cultivation',
#  'n(iku)_SEP__(iku)': 'unit',
#  'n(asz)_SEP__': 'field_area',
#  'gu4-suhub2_SEP_Gusuhub': 'Gusuhub',
#  'buru14_SEP__': 'harvest',
#  'a-pi4-sal4{ki}_SEP_Apisal': 'Apisal',
#  'lugal-e_SEP_lugal': 'king',
#  'ma2-gur8-mah_SEP_magurmah': 'great_barge',
#  '{d}en-lil2-x_SEP__': 'for_Enlil',
#  '{d}nin-lil2-ra_SEP_Ninlil': 'Ninlil',
#  'mu-ne-dim2_SEP_mu-nnee': '-a',
#  '{gesz}tug2-gurx(|SZE.KIN|)_SEP_tuggur': 'plow',
#  "lu2-igi-sa6-sa6-ta_SEP_Lu'igisasa": "Lu'igisasa",
#  'na-ba-sa2_SEP_Nabasa': 'Nabasa',
#  'diri_SEP_dirig': 'excess',
#  'ugu2-du6_SEP_Ugudu': 'Ugudu',
#  '{d}szara2_SEP_Szara': 'Szara',
#  'lugal-ma2-gur8-re_SEP_Lugalmagure': 'Lugalmagure',
#  'zabar-dab5_SEP_zabardab': 'official',
#  'szu-gid2_SEP_szugid': 'animal_designation',
#  'e2-muhaldim-sze3_SEP_emuhaldim': 'kitchen',
#  'ezem-an-na_SEP_Ezemanna': 'Ezemanna',
#  'limmu2-ba-ke4_SEP__': 'and_quarters',
#  'a2-bi2-a-bi-ih_SEP__': 'to_Ab-abi',
#  'sagi_SEP_sagi': 'cup_bearer',
#  'ARAD2-da-ni-ir_SEP__': 'his_servant',
#  'in-na-ba_SEP__': 'he_gifted',
#  'sar_SEP_sar': 'unit',
#  'u2_SEP_u': 'grass',
#  'sahar-ba_SEP_sahar': 'earth',
#  'kab2-ku5_SEP_kabkul': 'water_installation',
#  "a-u2-da-ta_SEP_A'uda": "A'uda",
#  'u2-du-{d}nin-a-ra-li-sze3_SEP_Uduninarali': 'Uduninarali',
#  'ki-BAD-ta_SEP_Kibad': 'Kibad',
#  'u3-sur_SEP_Usur': 'Usur',
#  'tir-sze3_SEP_tir': 'forest',
#  '5/6(disz)_SEP_5/6(disz)': 'one',
#  'kin_SEP_kig': 'work',
#  'sahar_SEP_sahar': 'earth',
#  '{d}nin-hur-sag-ka_SEP_Ninhursag': 'Ninhursag',
#  'engar_SEP_engar': 'farmer',
#  'nu-banda3-gu4_SEP_nubandagu': 'ox_overseer',
#  'sza3-sahar_SEP_szagsahar': 'earth_worker',
#  'e_SEP_eg': 'levee',
#  'sa-dur2-ra_SEP_sadurra': 'bottom',
#  'u3-wa-ri-da_SEP_Uwarida': 'Uwarida',
#  'iszib-e-ne_SEP_Iszibene': 'Iszibene',
#  '8(gesz2)_SEP_8(gesz2)': 'sixty',
#  'da-da_SEP_Dada': 'Dada',
#  'an-sza-an{ki}_SEP_Anszan': 'Anszan',
#  'na-ni_SEP_Nani': 'Nani',
#  'ur5-ra_SEP_urra': 'loan',
#  'lugal-me-lam2_SEP_Lugalmelam': 'Lugalmelam',
#  'ur-ma-ma_SEP_Urmama': 'Urmama',
#  'in-na-szum2-ma_SEP_i-nn-a': '-n',
#  '{u2}har-an_SEP_haran': 'plant',
#  'kab2-ku5-a_SEP_kabkul': 'water_installationr',
#  'de2-a_SEP_de': 'pour',
#  'u2-du-{d}nin-a-ra-li-ka_SEP_Uduninarali': 'Uduninarali',
#  'ur-{d}da-mu_SEP_Urdamu': 'Urdamu',
#  'inim-{d}inanna_SEP_Iniminanna': 'Iniminanna',
#  'szu-{d}idim-ta_SEP__': 'Szu-Idim',
#  'ezem-{d}nin-a-zu_SEP_Ezemninazu': 'Ezemninazu',
#  'lu-lu-bu{ki}_SEP_Lulubu': 'Lulubu',
#  '1(disz@t)-kam_SEP_1(disz)': 'one',
#  'dusu2-nita2_SEP__': 'jackasses',
#  'dusu2-munus_SEP__': 'jenny',
#  'ziz2_SEP_ziz': 'emmer',
#  '...{ki}_SEP__': '_',
#  'mah_SEP_mah': 'great',
#  'mu-ne-du3_SEP_mu-nnee': '-a',
#  'na-wi-ir-dingir_SEP__': 'Nawir-ilim',
#  'i3-du8_SEP_idu': 'doorkeeper',
#  'a-na-a_SEP__': 'Anaya',
#  'lukur-a-ni_SEP__': 'his_lukur',
#  'sag-nig2-gur11-e_SEP_': '',
#  'en-te_SEP__': 'wintertime',
#  'min-na-sze3_SEP__': 'over_two',
#  'ur-{d}da-mu-ta_SEP__': 'Ur-Damu',
#  'ur-ga2-gi4-a_SEP__': 'did_Ur-gagia',
#  'ba-ti-esz2_SEP_ba': '-n',
#  'bara2-za3-gar_SEP__': 'bara-zagar',
#  'zal-la_SEP_zal': 'pass',
#  'a-bu-ni_SEP_Abuni': 'Abuni',
#  'lu2_SEP_zah': 'disappear',
#  'zah3_SEP_': '',
#  'dab5-de3_SEP_gen': 'go',
#  "i3-udu_SEP_i'udu": 'sheep_fat',
#  'i-di3-zu_SEP_': '',
#  '{gesz}tukul-gu-la_SEP_tukulgal': 'big_weapon_carrier',
#  '<ninda>_SEP_ninda': 'bread',
#  "szu-er3-ra_SEP_Szu'era": "Szu'era",
#  "sze-il2-la_SEP_Sze'ila": "Sze'ila",
#  'sza3-tam_SEP_': '',
#  'a-gu-gu_SEP_Agugu': 'Agugu',
#  'lugal-ku3-ga-ni_SEP_Lugalkugani': 'Lugalkugani',
#  'si-i3-tum_SEP_situm': 'balance',
#  'nigin6_SEP__': 'xxx',
#  "me-{d}isztaran_SEP_Me'isztaran": "Me'isztaran",
#  'nin9_SEP__': 'sister',
#  '{d}iszkur-illat_SEP__': 'Adda-illat',
#  'a-bi2-a_SEP__': 'child_Abiya',
#  'didli_SEP_didli': 'several',
#  'masz-x-x_SEP__': 'sealed_documents_varied',
#  'lu2-gi-na-ta_SEP_Lugina': 'Lugina',
#  'de6-a_SEP_de': 'bring',
#  'am_SEP_am': 'bull',
#  'amar_SEP_amar': 'calf',
#  'pesz_SEP_pesz': 'thick',
#  "szu-esz5-sza_SEP_Szu'eszsza": "Szu'eszsza",
#  'a-gu_SEP_Agu': 'Agu',
#  'gaszam_SEP__': 'xxx',
#  'szabra_SEP_szabra': 'chief_administrator',
#  'ib2-dab5_SEP_': '',
#  'kuruszda-e_SEP__': 'xxx',
#  '{kusz}du10-gan-na_SEP_duggan': 'leather_bag',
#  'masz-da3-gu7-ta_SEP_Maszdagu': 'Maszdagu',
#  'sze-sag11-ku5-sze3_SEP_Szesagku': 'Szesagku',
#  'hu-uh2-<nu>-ri{ki}_SEP_Huhnuri': 'Huhnuri',
#  'u4-da_SEP_ud': 'day',
#  'e2-gal_SEP_egal': 'palace',
#  'siskur2_SEP_siszkur': 'offering',
#  'hi-ba-ri2-tum{ki}_SEP_Hibaritum': 'Hibaritum',
#  'min-esz3_SEP_Minesz': 'Minesz',
#  '{d}ga2-tum3-du10_SEP__': 'xxx',
#  'ses-da-gu7_SEP_Sesdagu': 'Sesdagu',
#  'sza-asz-ru{ki}_SEP_Szaszru': 'Szaszru',
#  "in-ta-e3-a_SEP_Inta'e'a": "Inta'e'a",
#  'gu-du-du-ta_SEP__': 'Gududu',
#  'umma{ki}-ka_SEP_Umma': 'Umma',
#  'lugal-e2-mah-e_SEP_Lugalemahe': 'Lugalemahe',
#  'duh_SEP_duh': 'bran',
#  'nig2-ar3-ra_SEP_nigara': 'groats',
#  'dabin_SEP_dabin': 'semolina',
#  '8(disz)-kam_SEP_8(disz)': 'one',
#  'mu-sza_SEP__': 'm-grain',
#  'e2-kiszib3-ba-ta!_SEP__': 'from_storage_facility',
#  'lu2-{d}suen_SEP_Lusuen': 'Lusuen',
#  'ur-sa6!-ga_SEP_Ursaga': 'Ursaga',
#  'sipa_SEP_sipa': 'shepherd',
#  'lu2-{d}ig-alim_SEP__': 'Lu-Igalim',
#  'ur-ki-gu-la_SEP__': 'Ur-kigula',
#  'sza3-tam-e-ne_SEP__': 'officials',
#  '1(disz)-ta_SEP_1(disz)': 'one',
#  '$)-kam_SEP__': 'months',
#  'mu-ri-iq-ti-id-ni-im_SEP_Muriqtidnim': 'Muriqtidnim',
#  "ki-uri_SEP_ki'uri": "ki'uri",
#  'ki-lu5-la-ta_SEP_Kilula': 'Kilula',
#  'ma-an-ba-ta_SEP_Manba': 'Manba',
#  'nigar{gar}-ki-du10-ta_SEP_Nigarkidu': 'Nigarkidu',
#  'a-kal-la-ta_SEP_Akala': 'Akala',
#  'sag-nig2-gur11-ra_SEP_sagnigGArak': 'available_assets',
#  'nu-banda3_SEP_nubanda': 'overseer',
#  'gu4-ke4-ne_SEP__': 'xxx',
#  'mu-dim2_SEP_': '',
#  'gin-a_SEP__': 'shekel',
#  '2(ban2)-ta_SEP__': 'ban_each',
#  '5(disz)-ta_SEP_': '',
#  'gin2-ta_SEP_gig': 'unit',
#  'masz-ku3-gu7_SEP_Maszkugu': 'Maszkugu',
#  'u5-bi2{muszen}-gu7_SEP_Ubigu': 'Ubigu',
#  'ki-siki-{d}nin-a-zu_SEP_Kisikininazu': 'Kisikininazu',
#  'ma-na-ta_SEP__': 'mina_each',
#  'har_SEP__': 'nose',
#  'giri17_SEP__': 'rings_for',
#  'ezem_SEP_ezem': 'festival',
#  'szu-numun-na-sze3_SEP__': 'and_Sowing',
#  'diri!_SEP_diri': 'intercalary_month',
#  '{d}nanna-dalla_SEP__': 'Nanna-dalla_in_possession',
#  'e2-gal-la_SEP_egal': 'palace',
#  'kux(KWU636)-ra_SEP__': 'in_delivered',
#  'nu-ur2!-..._SEP_': '',
#  'szu-e2-a_SEP_Szuea': 'Szuea',
#  'an-na-sze3_SEP_An': 'An',
#  'dam-gar3-ne_SEP__': 'merchants',
#  'masz-ku3-gu7-ta_SEP__': 'from_Gazelle-Feast',
#  'ezem-mah-sze3_SEP__': 'to_Great-Festival',
#  'iti-bi_SEP_iti': 'month',
#  'bad3-gal-bi_SEP_badgal': 'great_wall',
#  'ur-{d}namma_SEP_Urnamma': 'Urnamma',
#  '{d}en-lil2-la2_SEP_Enlil': 'Enlil',
#  'in-du3-a_SEP_i-n-du': 'build',
#  'gibil-sze3_SEP__': 'for_new',
#  'en-dingir-mu_SEP_Endingirmu': 'Endingirmu',
#  'a-mur-{d}suen_SEP__': 'Amur-Suen_runner',
#  'szesz-a-ni_SEP_Szeszani': 'Szeszani',
#  'ra2-gaba_SEP_ragaba': 'rider',
#  'en-mah-gal-an-na_SEP_Enmahgalana': 'Enmahgalana',
#  '{d}lamma_SEP__': 'To',
#  'tar-sir2-sir2-ra_SEP__': 'Guardian_Angel_Tarsirsira_temple',
#  'ama_SEP__': 'mother',
#  '{d}ba-ba6_SEP__': 'Baba',
#  'nin-a-ni_SEP_nin': 'lady',
#  "ki-en-<gi>_SEP_ki'engi": "ki'engi",
#  'ki-uri-ka-sze3_SEP__': 'and_and_Akkad',
#  'ha-la-{d}lamma_SEP__': 'Hala-Lamma',
#  'lagasz{ki}-ka-ke4_SEP__': 'of_Laga',
#  'e-la-ak-szu-qir-ra_SEP__': 'to_Elak-uqir',
#  'he2-na-ab-szum2-mu_SEP_ha-i-nn-a-b-szum': 'give',
#  'na-mi-gur-re_SEP_nan-m': '-b',
#  'gu2-na-kam_SEP__': 'it_is_his_burden',
#  'tukum-bi_SEP_tukumbi': 'if',
#  'nu-na-an-szum2_SEP__': 'not_give_to_him',
#  'e2-a-ni-ta_SEP__': 'it_will_out_his_own_household',
#  'ib2-su-su_SEP__': 'be_redeemed',
#  'ARAD2-{d}nanna_SEP_Aradnanna': 'Aradnanna',
#  'ka-guru7_SEP_kaguruk': 'supervisor',
#  'ur-{d}nansze-ta_SEP_Urnansze': 'Urnansze',
#  'szul-e2-du3-du3-e_SEP_Szuledudu': 'Szuledudu',
#  'gu4-ra2-bi2-mu2-mu2_SEP_Gurabimumu': 'Gurabimumu',
#  'an-sza{ki}_SEP_Anszan': 'Anszan',
#  'szul-e2-du3-du3_SEP_Szuledudu': 'Szuledudu',
#  'ba-..._SEP__': 'for',
#  '{d}utu-..._SEP__': 'for_Utu-',
#  '...-x-al-x-..._SEP__': 'for',
#  'lu2-{d}x_SEP__': 'for',
#  's,a-al-li2-a_SEP__': 'for',
#  'ur-{d}ba-ba6_SEP_Urbaba': 'Urbaba',
#  'i3!_SEP_i': 'oil',
#  'hu-la-ni-a_SEP__': 'for_ullniya',
#  'ha-ab-lu-lu_SEP__': 'for',
#  'suhusz-gi_SEP__': 'for',
#  'szu-{d}inanna_SEP__': 'for_Sz-Inanna',
#  'sza3-mu_SEP__': 'for_Szamu',
#  '{d}li9-si4_SEP_Lisi': 'Lisi',
#  'si-ma-num2{ki}_SEP_Simanum': 'Simanum',
#  'gaba-ri_SEP_gabari': 'copy',
#  'kiszib3-ba_SEP_kiszibba': 'sealed_tablets',
#  'siki_SEP_siki': 'wool',
#  'ku4-ra_SEP_kur': 'enter',
#  '{d}utu-GIR2@g-gal_SEP_UtuGIRgal': 'UtuGIRgal',
#  'ba-du3-sze3_SEP__': 'xxx',
#  'gu2-na_SEP_gun': 'tax',
#  'i3-la-...-ta_SEP__': '_',
#  'PA_SEP_ugula': 'overseer',
#  '{d}szu-{d}suen-e_SEP_Szusuen': 'Szusuen',
#  'na-mah_SEP_namah': 'magnificent_stone',
#  'a2-zi-da_SEP_Azida': 'Azida',
#  'ur-{d}nin-urta_SEP__': 'Ur-Ninurta',
#  'lugal-nam-tar-re-ta_SEP__': 'Lugal-namtare',
#  'ama-bi_SEP__': 'will_remit',
#  'gi4-gi4_SEP__': 'this_debt',
#  'a-sza3-mu_SEP__': 'That_My',
#  'a-e_SEP__': 'field_by',
#  'ba-ab-rex(HU)_SEP__': 'flooding_was_ruined_or',
#  'u4-de3_SEP_': '',
#  'nu-ub-be2-ne-a_SEP__': 'they_will_not_say',
#  'lugal-ra_SEP__': 'to_king',
#  'sanga_SEP_sagga': 'temple_administrator',
#  'nu-na-be2-ne-a_SEP__': 'or_chief_administrator_they_will_not_say',
#  'lugal-bi_SEP__': 'by_royal_name_has_sworn',
#  'i3-pa3-de3-esz2_SEP__': 'royal_name_they_have_sworn',
#  'en-am-gal_SEP_Enamgalanna': 'Enamgalanna',
#  'masz2-e_SEP_masz': 'goat',
#  'lu2-{d}lamma_SEP__': 'Lu-Lamma',
#  'nigin-ba_SEP__': 'grand_totals',
#  'siki-ba_SEP__': 'wool_rations',
#  'gir2-su{ki}-ta_SEP_Girsu': 'Girsu',
#  'gu2-ab-ba{ki}-sze3_SEP__': 'xxx',
#  'x-ri-ni{ki}_SEP__': 'Szipara',
#  'szi-pa-ra{ki}_SEP__': 'x-rini',
#  'mu-x_SEP_': '',
#  'szi-masz-gi5{ki}_SEP__': 'Szimaki',
#  'sa-bu-um{ki}_SEP__': 'and',
#  'bi-da-..._SEP__': 'also_Sabum',
#  'du8-du8-li2{ki}_SEP__': 'Duduli',
#  "'._SEP_": '',
#  'an-sza4-an{ki}_SEP__': 'Anan',
#  'unu{ki}_SEP_Unug': 'Unug',
#  'ur5-sze3_SEP_urra': 'loan',
#  'nu-tuku_SEP_nu-tuku': 'acquire',
#  'lugal-a2-zi-da-ta_SEP_Lugalazida': 'Lugalazida',
#  'sig4-ga-ka_SEP_Siga': 'Siga',
#  'su-su-dam_SEP_sug-sug': 'repay',
#  'ARAD2-dam_SEP_Aradam': 'Aradam',
#  "lu2-inim-ma-bi-me_SEP_lu'inimak": 'witness',
#  "apin-du8-a_SEP_Apindu'a": "Apindu'a",
#  'ba-zal_SEP_ba-zal': 'pass',
#  'us2-a_SEP_us': 'follow',
#  'lugal-engar-du10_SEP_Lugalengardu': 'Lugalengardu',
#  'dub_SEP_dub': 'tablet',
#  'lugal-a-ma-ru_SEP__': 'xxx',
#  'dida_SEP_dida': 'sweet_wort',
#  'la-ma-mu_SEP_Lamamu': 'Lamamu',
#  '{d}utu-mu_SEP_Utumu': 'Utumu',
#  "e2-iti-6(disz)_SEP_E'iti6": "E'iti6",
#  'hu-uh2_SEP_Huh': 'Huh',
#  'ur-e2-an-na_SEP__': 'Ur-Eanna',
#  '{uruda}ha-bu3-da_SEP_habuda': 'hoe',
#  'ki-la2-bi_SEP_kila': 'weight',
#  'da-da-ga-ta_SEP_Dadaga': 'Dadaga',
#  'ensi2-ke4_SEP_ensik': 'ruler',
#  'in-la2_SEP_i-n-la': 'weigh',
#  'szu-numun_SEP_Szunumun': 'Szunumun',
#  'us2-sa-bi_SEP_us': 'follow',
#  'GAN2-gu4_SEP_GANAgud': 'GANAgud',
#  'apin-la2_SEP_apinla': 'tenancy',
#  'kux(KWU147)-kux(KWU147)_SEP__': 'household_to_be',
#  'szuku-sze3_SEP__': 'for_prebend_doled',
#  'ha-la-a_SEP__': 'xxx',
#  'nig2-ka9_SEP_nigSZID': 'account',
#  'szi-im_SEP__': 'of_fields',
#  'didli-bi_SEP_': '',
#  '{d}gu-la_SEP_Gula': 'Gula',
#  '{d}nansze-GIR2@g-gal_SEP__': 'Nane-GIRgal',
#  'na-lu5_SEP_Nalu': 'Nalu',
#  'lu2-saga_SEP_Lusaga': 'Lusaga',
#  'ha-ba-mu_SEP__': 'Habamu',
#  'i3-li2-a_SEP__': 'Ilia',
#  'ur-szu_SEP__': 'Uru',
#  'muhaldim_SEP__': 'cook',
#  'ri-im-i3-li2_SEP__': 'Rim-ili',
#  'ab-ba-kal-la_SEP_Abbakala': 'Abbakala',
#  'lu2-{d}nin-gir2-su_SEP_Luningirsu': 'Luningirsu',
#  'id-gur2_SEP_idgurum': 'ladle',
#  "a-hu-a-ga_SEP_Ahu'aga": "Ahu'aga",
#  'sa-gaz-ak-sze3_SEP_Sagazak': 'Sagazak',
#  'gen-na_SEP_gen': 'go',
#  'KA_SEP_ka': 'mouth',
#  'inim-ma-ta_SEP_inim': 'word',
#  'KA-a-sze3_SEP_Kaya': 'Kaya',
#  'an-sza-an{ki}-ta_SEP_Anszan': 'Anszan',
#  'nibru{ki}-ta_SEP_Nibru': 'Nibru',
#  'nig2-dab5-ke4-ne_SEP__': 'takers',
#  'x-x-ke4-ne_SEP_': '',
#  'ma-ni_SEP__': 'Mani',
#  'szah2_SEP_szah': 'pig',
#  'ama-gan_SEP_amagan': 'breeding_female_animal',
#  'szah2-nita2_SEP_szahnita': 'male_pig',
#  'szah2-NE-tur_SEP_zahda': 'piglet',
#  'szu-kab-ta-sze3_SEP_Szukabta': 'Szukabta',
#  'ba-sa6-ga_SEP_Basaga': 'Basaga',
#  'zi-ga-am3_SEP_zig': 'expend',
#  'nig2-gur11_SEP_nigGA': 'property',
#  'sze-le2-pu-tum_SEP_Szeleputum': 'Szeleputum',
#  'dumu-munus_SEP_dumumunus': 'daughter',
#  'nu-hi-dingir_SEP_Nuhidingir': 'Nuhidingir',
#  'ba-a-ga_SEP_Bayaga': 'Bayaga',
#  'kuruszda_SEP_kuruszda': 'animal_fattener',
#  '3(u)-sze3_SEP_3(u)': 'ten',
#  'lugal-igi_SEP__': 'Lugal-igi',
#  'dumu-da-ba_SEP__': 'dumu-daba-laborers',
#  'ug3-IL2_SEP_uggaga': 'porter',
#  'ur-{d}gesz-bar-e3_SEP__': 'overseer_Ur-Gebare',
#  ...}

# %%
most_freq_tags
# Out:
# {'mu-na-gi-in_SEP__': 'ven.3-sg-h.dat.3-sg-h-a.gin.3-sg-p',
#  'nam-ti_SEP_namtil': 'n',
#  '{d}szul-gi-sze3_SEP__': 'rn.gen.term.np',
#  'x-sa6-ga_SEP__': 'pn.np',
#  'nu-kiri6_SEP__': 'n.erg',
#  'a_SEP_a': 'n.abs',
#  'mu-na-ru_SEP_mu-nn-a': 'ven.3-sg-h.dat.3-sg-h-a.vblex.3-sg-p',
#  'ur-ge6-par4_SEP_Ur-gepar': 'pn.np',
#  'u3-na-a-du11_SEP_u-nn-a-e-dug': 'ant.3-sg-h.dat.2-sg-a.vblex.3-sg-p',
#  'gurusz_SEP_gurusz': 'n',
#  '1(u)-am3_SEP_1(u)': 'num.abs.cop-3-sg',
#  'ma2_SEP_ma': 'n',
#  'dug_SEP_dug': 'n',
#  'ba-al-e-de3_SEP__': 'nf.vblex.pf.dat-nh',
#  'lu2-{d}szara2-ra_SEP__': 'pn.np',
#  'he2-na-szum2-mu_SEP__': 'mod.fin.3-sg-h.dat.3-sg-nh-p.vblex.3-sg-a',
#  'lu2_SEP_lu': 'n',
#  'us2-gar_SEP__': 'nf.vblex.3-sg-s',
#  'he2-eb-da-an-gi4-gi4_SEP__': 'mod1.fin.3-sg-nh-p.vblex.3-sg-a',
#  'lu2-kal-la_SEP_Lukala': 'pn.gen.np',
#  'dub-sar_SEP_dubsar': 'n',
#  'dumu_SEP_dumu': 'n',
#  'ur-sa6-ga_SEP_Ursaga': 'pn.np',
#  '{d}szu-{d}suen_SEP_Szusuen': 'rn.np',
#  'lugal_SEP_lugal': 'n',
#  'kal-ga_SEP_kalag': 'nf.vblex.sub',
#  'uri5{ki}-ma_SEP_Urim': 'sn.gen.np',
#  'an_SEP_An': 'n',
#  'ub-da_SEP_': 'n',
#  'limmu2-ba_SEP_limmu': 'nf.vblex.3-sg-nh-poss.gen.abs',
#  'a-ha-am-wa-qar_SEP__': 'pn.np',
#  'ARAD2-zu_SEP_arad': 'n.2-sg-poss.abs',
#  'pisan-dub-ba_SEP_bisagdubak': 'n',
#  'gesztu2-ga_SEP__': 'n',
#  'ru_SEP__': 'vblex',
#  'a-zu_SEP__': 'n.term',
#  'i3-gal2_SEP_i': 'fin.l1.vblex.3-sg-s',
#  'e2-tum_SEP_bitum': 'n',
#  'ab2_SEP_ab': 'n',
#  'e2-tur3_SEP_etur': 'n',
#  'u3_SEP_u': 'cnjcoo',
#  'gu4-{gesz}apin_SEP_gudapin': 'n.gen.gen',
#  'mu_SEP_mu': 'n',
#  'gu-za_SEP_guza': 'n',
#  'ba-dim2_SEP_ba-dim': 'mid.vblex.3-sg-s',
#  '1(disz)_SEP_1(disz)': 'num',
#  'udu-nita2_SEP_udunita': 'n',
#  'ba-usz2_SEP_ba-usz': 'mid.vblex.3-sg-s',
#  'sila4_SEP_sila': 'n',
#  'ASZ-ur4_SEP_azur': 'n',
#  'ki_SEP_ki': 'n',
#  'ur-u3-ta_SEP_Uru': 'pn.gen.abl.np',
#  'sza3_SEP_szag': 'n',
#  'bala-a_SEP_bala': 'n.gen.l1',
#  'kiszib3_SEP_kiszib': 'n',
#  'ARAD2_SEP_Arad': 'pn.erg.np',
#  'iti_SEP_iti': 'n',
#  'sze-sag11-ku5_SEP_Szesagku': 'mn.l1.np',
#  'us2-sa_SEP_us': 'nf.vblex.pt',
#  'ki-masz{ki}_SEP_Kimasz': 'sn.abs.np',
#  'ba-hul_SEP_ba-hulu': 'mid.vblex.3-sg-s',
#  'ARAD2-mu_SEP_Aradmu': 'pn.np',
#  'ur-nigar{gar}_SEP_Urnigar': 'pn.np',
#  'szusz3_SEP_kusz': 'n.gen',
#  'udu_SEP_udu': 'n',
#  'u8_SEP_u': 'n',
#  'masz2-gal_SEP_maszgal': 'n',
#  'ba-usz2_SEP_ba-ug': 'mid.vblex.pl.3-pl-s',
#  'u4_SEP_ud': 'n',
#  '1(u)_SEP_1(u)': 'num',
#  'la2_SEP_la': 'nf.vblex.abs',
#  '1(disz@t)-kam_SEP_1(disz@t)': 'num.gen.cop-3-sg',
#  'tum-ma-al_SEP_Tummal': 'sn.gen.l1.np',
#  'en-dingir-mu-ta_SEP_Endingirmu': 'pn.gen.abl.np',
#  "{d}szul-gi-iri-mu_SEP_Szulgi'irimu": 'pn.erg.np',
#  'szu_SEP_szu': 'n.l3-nh',
#  'ba-ti_SEP_ba': 'mid.3-sg-h-a.vblex.3-sg-p',
#  'a2-ki-ti_SEP_Akiti': 'mn.l1.np',
#  'en_SEP_en': 'n',
#  '{d}nanna_SEP_Nanna': 'dn.np',
#  'ba-hun_SEP_ba-hug': 'mid.vblex.3-sg-s',
#  '1/3(disz)_SEP_1/3(disz)': 'num',
#  'gin2_SEP_gig': 'n',
#  '2(u)_SEP_2(u)': 'num',
#  'sze_SEP_sze': 'n',
#  '3(disz)_SEP_3(disz)': 'num',
#  'igi-6(disz)-gal2_SEP_igi6(disz)': 'num',
#  'bi2-tum_SEP_': 'pn.np',
#  'e2-szu-sum-ma_SEP__': 'pn.np',
#  'n_SEP__(_)': 'num',
#  'ku3_SEP_kug': 'n',
#  'masz_SEP_masz': 'n',
#  'a-sza3-ga_SEP_aszag': 'n.gen',
#  'ur-dun-ta_SEP__': 'pn.gen.abl.np',
#  'da-da-ga_SEP_Dadaga': 'pn.np',
#  'ur-bi2-lum{ki}_SEP_Urbilum': 'sn.abs.np',
#  'dub-gid2-da_SEP__': 'n',
#  'lu2-{d}ba-ba6_SEP_Lubaba': 'pn.np',
#  'ba-lu5_SEP_Balu': 'n',
#  'lu2-gu-la_SEP_Lugula': 'pn.np',
#  'ur-{d}igi-zi-bar-ra_SEP_Urigizibarra': 'pn.gen.np',
#  'ha-ar-szi{ki}_SEP_Harszi': 'sn.np',
#  'hu-ur5-ti{ki}_SEP_Hurti': 'sn.abs.np',
#  'ur-ba-gara2_SEP_Urbagara': 'pn.np',
#  'ur-{d}..._SEP__': 'pn.gen.np',
#  'nig2-ka9-ak_SEP_nigSZID': 'n',
#  'a2_SEP_a': 'n',
#  'erin2-na_SEP_erin': 'n.gen',
#  'en-unu6_SEP_': 'pn.np',
#  '{d}inanna_SEP_Inanna': 'dn.np',
#  'ba-hun-ta_SEP__': 'mid.vblex.3-sg-s.abl',
#  'sza-asz-ru-um{ki}-sze3_SEP__': 'sn.gen.gen.term.np',
#  'szuku-ra_SEP_szukur': 'n.gen',
#  'ak_SEP_ak': 'nf.vblex.pt',
#  'dam-gar3_SEP_damgar': 'n',
#  'gar-ra-ke4-ne_SEP__': 'vblex',
#  'masz-e_SEP_masz': 'n.l3-nh',
#  'i3-pa3_SEP_i-pad': 'fin.vblex.3-sg-s',
#  'gurum2_SEP_gurum': 'n',
#  'sag-apin_SEP__': 'n',
#  'e2_SEP_e': 'n',
#  '{d}en-lil2_SEP_Enlil': 'dn.np',
#  '{d}en-ki_SEP_Enki': 'dn.gen.abs.np',
#  '{d}nin-gul_SEP__': 'dn.np',
#  '{d}dumu-zi_SEP_Dumuzi': 'mn.l1.np',
#  'nam-ha-ni_SEP_Namhani': 'pn.np',
#  '{d}nin-dar-a_SEP__': 'dn.np',
#  '5(u)_SEP_5(u)': 'num',
#  '5(asz)_SEP_5(asz)': 'num',
#  '2(barig)_SEP_2(bariga)': 'n',
#  'gur_SEP_gur': 'n',
#  '1/2(disz)_SEP_1/2(disz)': 'num',
#  'ma-na_SEP_mana': 'n',
#  '8(disz)_SEP_8(disz)': 'num',
#  '2/3(disz)_SEP_2/3(disz)': 'num',
#  '5(disz)_SEP_5(disz)': 'num',
#  'ku3-babbar_SEP_kugbabbar': 'n',
#  'mu-kux(DU)_SEP_mukur': 'n',
#  'ad-da-kal-la_SEP_Addakala': 'pn.np',
#  '1(disz)-sze3_SEP_1(disz)': 'num.term',
#  'tir_SEP_tir': 'n.gen',
#  'szum2-bad3-x_SEP__': 'pn.np',
#  '{gesz}u2-bil2-x_SEP__': 'pn.np',
#  'ga-ma-la_SEP__': 'pn.np',
#  'ugula_SEP_ugula': 'n',
#  'ur-am3-ma_SEP_Uramma': 'pn.np',
#  'lugal-nir_SEP_Lugalnir': 'pn.np',
#  'ezem-{d}szul-gi_SEP_Ezemszulgir': 'mn.l1.np',
#  'na-ru2-a_SEP_narua': 'n',
#  'ba-du3_SEP_ba-du': 'mid.vblex.3-sg-s',
#  'ur-{d}szara2_SEP_Urszara': 'pn.np',
#  'sza13-dub-ba-ka_SEP_bisagdubak': 'n.gen',
#  'niga_SEP_niga': 'nf.vblex.abs',
#  'gukkal_SEP_gukkal': 'n',
#  '2(disz)_SEP_2(disz)': 'num',
#  '{munus}asz2-gar3_SEP_aszgar': 'n',
#  'a-bi2-si2-im-ti_SEP_Abisimti': 'pn.gen.np',
#  'u4-sakar_SEP_usakar': 'n.term',
#  'ri-zi-dingir_SEP__': 'pn.np',
#  'maszkim_SEP_maszkim': 'n.abs',
#  'lugal-ma2!-gur8-re_SEP_Lugalmagure': 'pn.np',
#  '..._SEP__': 'n',
#  '{d}nin-lil2_SEP_Ninlil': 'dn.np',
#  '{d}nin-urta_SEP_Ninurta': 'dn.np',
#  '...-zi_SEP_': 'pn.np',
#  'mu-kux(DU)-ra-ta_SEP__': 'n',
#  '6(disz)-kam_SEP_6(disz)': 'num.gen.cop-3-sg',
#  'ab-ba-sa6-ga-ta_SEP_Abbasaga': 'pn.gen.abl.np',
#  'ba-zi_SEP_ba-zig': 'mid.vblex.3-sg-s',
#  'ezem-mah_SEP_Ezemmah': 'mn.l1.np',
#  'en-unu6-gal_SEP_Enunugal': 'pn.np',
#  '1(ban2)_SEP_1(ban)': 'n',
#  'sila3_SEP_sila': 'n',
#  'i3-nun_SEP_inun': 'n',
#  '6(disz)_SEP_6(disz)': 'num',
#  'ga_SEP_ga': 'n',
#  'gazi_SEP_gazi': 'n',
#  'ur-mes-ta_SEP_Urmes': 'pn.gen.abl.np',
#  'ur-{d}dumu-zi_SEP_Urdumuzi': 'pn.erg.np',
#  'szu-gar-gal_SEP_Szugargal': 'mn.l1.np',
#  "5(gesz'u)_SEP_5(gesz'u)": 'num',
#  '9(gesz2)_SEP_9(gesz)': 'num',
#  '5/6(asz)_SEP_': 'num',
#  'gu2_SEP_gun': 'n',
#  'gi-zi_SEP_gizi': 'n.gen.gen',
#  'puzur4-isz-{d}da-gan_SEP_Puzuriszdagan': 'sn.abs.np',
#  "2(gesz'u)_SEP_2(gesz'u)": 'num',
#  '3(gesz2)_SEP_3(gesz)': 'num',
#  '4(u)_SEP_4(u)': 'num',
#  '6(asz)_SEP_6(asz)': 'num',
#  'nibru{ki}_SEP_Nibru': 'sn.gen.abs.np',
#  '1(szar2)_SEP_1(szar)': 'n',
#  '1(asz)_SEP_1(asz)': 'num',
#  'sza3-gal_SEP_szaggal': 'n',
#  'niga-sze3_SEP__': 'nf.vblex.3-sg-nh-poss.gen.gen.term',
#  'erin2_SEP_erin': 'n',
#  'gir2-su{ki}_SEP_Girsu': 'sn.gen.np',
#  'sukkal-mah_SEP__': 'n',
#  '{d}szul-gi-i3-li2_SEP_Szulgirili': 'pn.np',
#  'giri3_SEP_giri': 'n',
#  'lu2-giri17-zal_SEP_Lugirizal': 'pn.np',
#  'masz-da3-gu7_SEP_Maszdagu': 'mn.l1.np',
#  '{d}i-bi2-{d}suen_SEP_Ibbisuen': 'rn.np',
#  '7(disz)_SEP_7(disz)': 'num',
#  'masz2_SEP_masz': 'n',
#  'ud5_SEP_uzud': 'n',
#  'e2-muhaldim_SEP_emuhaldim': 'n.term',
#  '5(disz)-kam_SEP_5(disz)': 'num.gen.cop-3-sg',
#  'zi-ga_SEP_zig': 'nf.vblex.pt',
#  'ur-ku3-nun-na_SEP_Urkununa': 'pn.np',
#  'ki-masz2_SEP_': 'gn.np',
#  'di_SEP_did': 'n',
#  'til-la_SEP_til': 'nf.vblex.pt',
#  'puzur4-isz-da-gan_SEP__': 'sn.abs.np',
#  'kasz_SEP_kasz': 'n',
#  'saga_SEP_saga': 'nf.vblex.abs',
#  'ninda_SEP_ninda': 'n',
#  'i3_SEP_i': 'n',
#  'naga_SEP_naga': 'n',
#  'ku6_SEP_kud': 'n',
#  'sa_SEP_sa': 'n',
#  'szum2_SEP_szum': 'n',
#  'lu2-{d}nanna_SEP_Lunanna': 'pn.np',
#  'ur-{d}nanna_SEP__': 'pn.np',
#  '3(ban2)_SEP_3(ban)': 'n',
#  'du_SEP_gin': 'nf.vblex.abs',
#  'i3-gesz_SEP_igesz': 'n',
#  'kas4-e-ne_SEP__': 'n.pl',
#  '1(disz)-kam_SEP_1(disz)': 'num.gen.cop-3-sg',
#  'sig4-{gesz}i3-szub-ba-gar_SEP_Sigiszubbagar': 'mn.l1.np',
#  '4(disz)-sze3_SEP_4(disz)': 'num.term',
#  'kar_SEP__': 'n',
#  'umma{ki}-ta_SEP_Umma': 'sn.gen.abl.np',
#  'iri-sa12-rigx(|PA.MUNUS.HUB2.DU|){ki}-sze3_SEP__': 'sn.gen.term.np',
#  'gid2-da_SEP_gid': 'nf.vblex.pt',
#  'ma2-a_SEP_ma': 'n.l1',
#  'si-ga_SEP_sig': 'nf.vblex.pt',
#  'iri-sa12-rigx(|PA.MUNUS.HUB2.DU|){ki}-ta_SEP__': 'sn.gen.abl.np',
#  '2(disz)-sze3_SEP_2(disz)': 'num.term',
#  'kun-zi-da_SEP_kunzida': 'n',
#  '{gesz}kiri6_SEP_kiri': 'n',
#  'gesztin-sze3_SEP__': 'n.3-sg-h-poss.term',
#  'diri-ga_SEP_dirig': 'nf.vblex.pt',
#  '8(disz)-sze3_SEP_8(disz)': 'num.term',
#  'e2-duru5_SEP_eduru': 'n',
#  'uri3-ru2-a-ta_SEP__': 'gn.np',
#  'i7_SEP_id': 'n',
#  '{d}amar-{d}suen-ni-tum-sze3_SEP__': 'wn.np',
#  'ga6-ga2_SEP_gag': 'nf.vblex.pt',
#  '{d}amar-{d}suen-ni-tum-ma-ta_SEP__': 'dn.np',
#  'bala_SEP_bala': 'n.l1',
#  'ka_SEP_kag': 'n',
#  'da-mi-ma-ma-sze3_SEP__': 'vblex',
#  'umma{ki}-sze3_SEP__': 'sn.gen.term.np',
#  'ba-al-la_SEP_bala': 'nf.vblex.pt',
#  "i7-pa-e3_SEP_Ipa'e": 'pn.np',
#  'a-du-mu_SEP_Adumu': 'pn.gen.np',
#  'ba-ab-du8_SEP_ba-b-du': 'mid.3-sg-nh-l3.vblex.3-sg-s',
#  'ur-{d}suen_SEP_Ursuen': 'pn.np',
#  'ur-{gesz}gigir_SEP_Urgigir': 'pn.np',
#  'sza3-tam_SEP__': 'n.abs',
#  'sze-ba_SEP_szeba': 'n',
#  'giri3-se3-ga_SEP_girsiga': 'n',
#  'ugnim{ki}_SEP__': 'gn.np',
#  'an-na-hi-li-bi-ta_SEP_Annahilibi': 'pn.gen.abl.np',
#  "pa4-u2-e_SEP_Pa'u'e": 'mn.l1.np',
#  "ur-e11-e_SEP_Ure'e": 'pn.np',
#  'usz2_SEP_usz': 'nf.vblex.abs',
#  'ur-sila-luh_SEP__': 'n',
#  '1(asz@c)_SEP_1(asz)': 'num',
#  'GAN2_SEP_gana': 'n',
#  "e2-ur2-bi-du10_SEP_E'urbidu": 'pn.erg.np',
#  "giri3-ni-i3-sa6_SEP_Girini'isa": 'pn.np',
#  'dumu-ni-me_SEP_dumu': 'n.3-sg-h-poss.abs.cop-3-pl',
#  'ur-{d}gesztin-an-ka_SEP_Urgesztinanka': 'pn.erg.np',
#  'lu2-{d}sukkal-an-ka_SEP_Lusukkalankak': 'pn.dat-h.np',
#  'ki-sur-ra_SEP__': 'n',
#  'i3-dab5_SEP_i': 'fin.3-sg-h-a.vblex.3-sg-p',
#  '1(barig)_SEP_1(bariga)': 'n',
#  '4(disz)_SEP_4(disz)': 'num',
#  'ug3_SEP_ug': 'n',
#  'du11-ga-ni_SEP_Dugani': 'pn.dat-h.np',
#  'szu-na-mu-gi4_SEP__': 'pn.gen.abl.np',
#  'inim-{d}szara2_SEP_Inimszara': 'pn.np',
#  'lugal-inim-gi-na_SEP_Lugalinimgina': 'pn.np',
#  'dumu-ni_SEP_dumu': 'n.3-sg-h-poss',
#  'a-kun-kum2_SEP__': 'fn.np',
#  'ur-ab-ba_SEP_Urabba': 'pn.gen.np',
#  'lu2-{d}szara2_SEP_Luszara': 'pn.np',
#  'ka-ma-ri2{ki}_SEP_Kamari': 'fn.gen.l1.np',
#  'lugal-iti-da_SEP_Lugalitida': 'pn.np',
#  'lu2-gi-na_SEP_Lugina': 'pn.gen.np',
#  'a-hu-ba-qar_SEP__': 'pn.np',
#  'a-ta2-na-ah_SEP__': 'pn.np',
#  'a-sza3_SEP_aszag': 'n',
#  'am3-ri2_SEP__': 'pn.np',
#  "lu2-{d}ab-u2_SEP_Lu'abu": 'pn.erg.np',
#  "lu2-eb-gal_SEP_Lu'ebgal": 'pn.np',
#  'lu2-{d}en-ki-du_SEP__': 'pn.np',
#  'da-a-da-ga_SEP__': 'vblex',
#  'u2-la2{ki}_SEP__': 'sn.np',
#  'a-du-du_SEP_Adudu': 'pn.np',
#  'lugal-ku3-zu_SEP_Lugalkuzu': 'pn.np',
#  '{gesz}kiri6-mah_SEP__': 'n',
#  'nu_SEP_nu': 'nf.vblex.abs',
#  'inim-ma-ni-zi_SEP_Inimanizi': 'pn.np',
#  'ur-e2-mah_SEP_Uremah': 'pn.np',
#  '{d}utu-saga_SEP__': 'pn.np',
#  'ur-{d}ur3-bar-tab_SEP__': 'pn.np',
#  'dul4-la_SEP__': 'pn.np',
#  'sza3-gu2-bi_SEP_Szagubi': 'pn.dat-h.np',
#  'zah3_SEP_zah': 'nf.vblex.pt',
#  '{d}szara2-si_SEP__': 'pn.np',
#  'ur-e2-masz_SEP_Uremasz': 'pn.np',
#  'da-gu-na_SEP__': 'pn.np',
#  'szesz-kal-la_SEP_Szeszkala': 'pn.np',
#  'lugal-hi-li_SEP_Lugalhili': 'pn.np',
#  '{d}szara2-zi-da_SEP__': 'pn.gen.abs.np',
#  'al-lu-me_SEP__': 'pn.np',
#  'e2-lugal_SEP__': 'pn.gen.np',
#  'a-kal-la_SEP_Akala': 'pn.np',
#  'ur-tul2-mah_SEP_Urtulmah': 'pn.gen.np',
#  'kar-ra_SEP__': 'vblex',
#  'lugal-he2-gal2_SEP_Lugalhegal': 'pn.np',
#  'ma-sar_SEP__': 'pn.np',
#  'lu2-dingir-ra_SEP_Ludingira': 'pn.np',
#  'ur-lugal_SEP_Urlugal': 'pn.np',
#  'tu-ru-da_SEP__': 'pn.erg.np',
#  'ur-gu_SEP_Urgu': 'pn.np',
#  'lu2-{d}nin-a-zu_SEP__': 'pn.np',
#  'nag-su{ki}_SEP__': 'sn.np',
#  'lugal-za3-ge_SEP_Lugalzage': 'pn.erg.np',
#  'gir13-gesz{ki}_SEP__': 'sn.gen.abs.np',
#  'a2-ta_SEP_Ata': 'pn.np',
#  'inim-e3_SEP__': 'wn.np',
#  'ab-ba-saga_SEP_Abbasaga': 'pn.np',
#  'bala-a-ti-im-durunx(|KU.KU|)_SEP__': 'pn.np',
#  '{d}szara2-kam_SEP_Szarakam': 'pn.np',
#  'adab{ki}_SEP__': 'sn.gen.abs.np',
#  'ba-an-sa6_SEP_Bayansa': 'pn.erg.np',
#  'ur-sukkal_SEP__': 'pn.np',
#  'zabala3{ki}_SEP__': 'sn.gen.np',
#  'gal-la_SEP__': 'nf.vblex.3-sg-nh-poss.gen.gen.term',
#  'ARAD2_SEP_arad': 'n',
#  'lu2-he2-gal2_SEP_Luhegal': 'pn.erg.np',
#  'ha-la-{d}ma-mi_SEP__': 'pn.gen.dat-h.np',
#  'lugal-nesag-e_SEP_Lugalnesage': 'pn.np',
#  'gar-sza-na-ka{ki}_SEP__': 'sn.gen.abs.np',
#  "i-di3-a_SEP_Idi'a": 'pn.dat-h.np',
#  'erin2-gar-sza-na-ka{ki}_SEP__': 'sn.np',
#  'lu2-ga_SEP_Luga': 'pn.gen.np',
#  'ur-{d}dumu-zi-da_SEP_Urdumuzida': 'pn.gen.abs.np',
#  'ur-mes_SEP_Urmes': 'pn.np',
#  'sza3-nin9-ti-na_SEP__': 'pn.np',
#  'sza3-ku3-sig17_SEP__': 'pn.erg.np',
#  'gaba-ri-gar-sza-na-ka_SEP__': 'pn.np',
#  'ma2-szuku-diri_SEP__': 'n.2-sg-poss.abs',
#  'ARAD2-{d}szara2_SEP_Aradszara': 'pn.gen.np',
#  'ha-an-da_SEP__': 'pn.gen.dat-h.np',
#  'nu-{gesz}kiri6_SEP__': 'n',
#  'uku2-nu-ti_SEP_': 'fn.abl.np',
#  '{d}szul-gi-he2-gal2_SEP__': 'wn.np',
#  'ab-ba-gi-na_SEP_Abbagina': 'pn.np',
#  'da-a-a_SEP__': 'pn.np',
#  'im-e_SEP__': 'n.l3-nh',
#  'tak4-a_SEP_taka': 'nf.vblex.pt',
#  'iri-bu3-ra_SEP__': 'sn.np',
#  'lal3-mes_SEP_Lalmes': 'pn.erg.np',
#  'a-du10-ga-nigin_SEP__': 'pn.np',
#  'a-bu-du10_SEP__': 'pn.np',
#  'gar-su4-da_SEP__': 'vblex',
#  'lugal-da-ga_SEP__': 'pn.np',
#  'ama-ki_SEP__': 'pn.dat-h.np',
#  'pa4_SEP__': 'n',
#  'ur-{d}isztaran_SEP_Urisztaran': 'pn.gen.abs.np',
#  'GAN2-masz{ki}_SEP__': 'sn.np',
#  'szunigin_SEP_szunigin': 'n',
#  '3(asz@c)_SEP_3(asz)': 'num',
#  'dumu-nita2_SEP__': 'n',
#  'diri_SEP_diri': 'n',
#  'szu-gi4_SEP__': 'pn.np',
#  '2(u@c)_SEP_2(u)': 'num',
#  'nu-dab_SEP__': 'vblex',
#  '4(asz@c)_SEP_4(asz)': 'num',
#  'siki-ta_SEP__': 'n',
#  'ug3-IL2-me_SEP__': 'pn.dat-h.np',
#  'sze-bi_SEP_sze': 'n.3-sg-nh-poss.abs',
#  'iti-da_SEP_itud': 'n',
#  'be6-dam_SEP__': 'vblex',
#  'siki-bi_SEP_siki': 'n.3-sg-nh-poss.abs',
#  'mu-a_SEP_': 'n',
#  'dab-ba_SEP_dab': 'nf.vblex.pt',
#  'tir-ra_SEP__': 'n.gen.gen',
#  'a-a-kal-la_SEP_Ayakala': 'pn.np',
#  'ensi2_SEP_ensik': 'n',
#  'umma{ki}_SEP_Umma': 'sn.gen.abs.np',
#  'sza3-ta-ku3-zu_SEP_Szatakuzu': 'pn.np',
#  'sukkal_SEP_sukkal': 'n',
#  "lu2-{d}inanna_SEP_Lu'inanna": 'pn.np',
#  'ezem-{d}dumu-zi_SEP_Ezemdumuzi': 'mn.l1.np',
#  'en-nun-ne2-{d}amar-{d}suen-ra-ki-ag2_SEP__': 'pn.erg.np',
#  'eridu{ki}_SEP_Eridug': 'sn.gen.abs.np',
#  'igi-pesz2_SEP__': 'pn.np',
#  'ur-{d}iszkur_SEP_Uriszkur': 'pn.np',
#  "1(gesz'u)_SEP_1(gesz'u)": 'num',
#  'pa-ku5_SEP_pakud': 'n',
#  'gu-nigin2-ba_SEP_gunigin': 'n.3-sg-nh-poss.l1',
#  'sa-ta_SEP_sa': 'n.abl',
#  '{gesz}dal_SEP_dal': 'n',
#  '5(gesz2)_SEP_5(gesz)': 'num',
#  'ma-nu_SEP_manu': 'n',
#  'nig2-ba_SEP_nigba': 'n',
#  'sig4-te-la2-ni_SEP_Sigtelani': 'pn.erg.np',
#  'szu-ma-ma_SEP_Szumama': 'pn.dat-h.np',
#  'kin-gi4-a_SEP_kiggia': 'n',
#  'lu2-tur-tur_SEP_Luturtur': 'pn.np',
#  '3(u)_SEP_3(u)': 'num',
#  'ur-{d}nin-lil2-la2_SEP_Urninlila': 'pn.np',
#  'ka(SAG)-guru7_SEP_kaguruk': 'n.abs',
#  'ur-sila-luh-ta_SEP_Ursilaluh': 'pn.gen.abl.np',
#  'ensi2-ka_SEP_ensik': 'n.gen',
#  '{d}amar-{d}suen_SEP_Amarsuen': 'rn.np',
#  '{d}szul-gi_SEP_Szulgir': 'rn.np',
#  'nita_SEP_nita': 'n',
#  'an-ub-da_SEP_anubda': 'n',
#  'ur-{d}li9-si4_SEP_Urlisi': 'pn.np',
#  'gu-za-la2-e-ne_SEP__': 'n.pl',
#  'uri5{ki}-ma-ke4_SEP_Urim': 'sn.gen.erg.np',
#  'ma-da_SEP_mada': 'n',
#  'za-ab-sza-li{ki}_SEP_Zabszali': 'sn.gen.abs.np',
#  'mu-hul_SEP_mu': 'ven.3-sg-h-a.vblex.3-sg-p',
#  '(x)_SEP__': 'n',
#  'an-na-he-gal2_SEP__': 'pn.gen.abl.np',
#  'ma2-gur8-re_SEP_Magure': 'pn.np',
#  'gu4_SEP_gud': 'n',
#  '{d}nin-gir2-su_SEP_Ningirsu': 'dn.np',
#  '{d}ig-alim_SEP__': 'dn.np',
#  'uri5{ki}-ma!_SEP_Urim': 'sn.gen.np',
#  'ur-{d}utu!_SEP_Urutu': 'pn.np',
#  'ARAD2-da-ne2_SEP__': 'n.3-sg-h-poss.erg',
#  '9(asz)_SEP_9(asz)': 'num',
#  'gin2-a_SEP__': 'pn.np',
#  'ku3-bi_SEP_kug': 'n.3-sg-nh-poss.abs',
#  '9(disz)_SEP_9(disz)': 'num',
#  'lugal-pirig-banda3-ta_SEP__': 'pn.gen.abl.np',
#  'sag-nig2-gur11-ra-kam_SEP_sagnigGArak': 'n.abs.cop-3-sg',
#  'sza3-bi-ta_SEP_szag': 'n.3-sg-nh-poss.abl',
#  '3(asz)_SEP_3(asz)': 'num',
#  'esir2_SEP_esir': 'n',
#  'E2-A_SEP_Ea': 'on.np',
#  'lugal-ta_SEP_lugal': 'n.gen.abl',
#  '4(barig)_SEP_4(bariga)': 'n',
#  '2(ban2)_SEP_2(ban)': 'n',
#  '3(ban2)-ta_SEP_3(ban)': 'n.abl',
#  '1/3(disz){sza}_SEP_1/3(disz)': 'num',
#  'za-ha-din_SEP__': 'fn.np',
#  'sila3-ta_SEP_sila': 'n.abl',
#  'szum2-sikil_SEP__': 'vblex',
#  '4(ban2)-ta_SEP__': 'num',
#  '3(barig)_SEP_3(bariga)': 'n',
#  '4(ban2)_SEP_4(ban)': 'n',
#  'gaz_SEP_gaz': 'n',
#  'igi-4(disz)-gal2_SEP_igi4(disz)': 'num',
#  '4(asz)_SEP_4(asz)': 'num',
#  'gur-ta_SEP_gur': 'n.abl',
#  'igi-3(disz)-gal2_SEP_': 'num',
#  'mun_SEP_mun': 'n',
#  '2/3(|NINDA2x(SZE.2(ASZ))|)_SEP_': 'num.gen',
#  '{gesz}u3-suh5_SEP_usuh': 'n',
#  'gesz_SEP_gesz': 'n',
#  'e2-szum-ta!_SEP__': 'pn.gen.abl.np',
#  'igi-3(disz)-gal2_SEP__': 'num',
#  '{gesz}pesz3_SEP_pesz': 'n',
#  'duru5_SEP__': 'vblex',
#  'zu2-lum_SEP_zulum': 'n',
#  'had2_SEP_had': 'nf.vblex.abs',
#  'gu2-ta_SEP__': 'n',
#  "la2-ia3_SEP_la'u": 'n',
#  "ur-{d}szul-pa-e3_SEP_Urszulpa'e": 'pn.np',
#  'ezem-sze-il2-la_SEP__': 'mn.l1.np',
#  'GAN2-masz_SEP_GANmasz': 'mn.l1.np',
#  '2(disz)-kam_SEP_2(disz)': 'num.gen.cop-3-sg',
#  'bala-bi_SEP__': 'n',
#  '1(disz)-am3_SEP_': 'num.gen.cop-3-sg',
#  'ur-{d}lamma_SEP_Urlamma': 'pn.np',
#  'si-mu-ru-um{ki}_SEP_Simurrum': 'sn.abs.np',
#  'lu-lu-bu-um{ki}_SEP_Lulubum': 'sn.abs.np',
#  'a-ra2_SEP_ara': 'n',
#  '9(disz)-kam-asz_SEP_': 'num.gen.cop-3-sg.term',
#  "la2-ia3-ta_SEP_la'u": 'n.abl',
#  'su-ga_SEP_sug': 'nf.vblex.pt',
#  'ISZ-su{ki}_SEP_Iszsu': 'sn.np',
#  "lu2-sa6-i3-zu-ta_SEP_Lusa'izu": 'pn.gen.abl.np',
#  '...-x-ni_SEP__': 'pn.erg.np',
#  'dal_SEP_Dal': 'mn.l1.np',
#  'bad3_SEP_bad': 'n',
#  'ur-{d}nansze_SEP_Urnansze': 'pn.np',
#  'dab5_SEP_': 'vblex',
#  'lu2-{d}na-ru2-a-ka-ra_SEP__': 'pn.np',
#  'esz2-giri17-sze3_SEP__': 'n.3-sg-h-poss.term',
#  'na-ba-du3_SEP_nan-ba': 'mod.mid.l2.vblex.pf.3-sg-s',
#  'lugal-ezem_SEP_Lugalezem': 'pn.np',
#  'ur-kun_SEP_Urkun': 'pn.gen.np',
#  'nin-a-ni-ir_SEP__': 'n.3-sg-h-poss.dat-h',
#  'a-tu_SEP_Atu': 'pn.np',
#  'nigar{gar}-ki-du10_SEP_Nigarkidu': 'pn.np',
#  'gal5-la2-gal_SEP__': 'n',
#  'gesz-gi_SEP__': 'n',
#  'mar-sa_SEP_marsa': 'n',
#  'e2-uzu_SEP__': 'pn.np',
#  'ezem-{d}szul-gi-ta_SEP_Ezemszulgir': 'mn.abl.np',
#  '{d}nin-gal-e2-nun-na_SEP__': 'pn.np',
#  'a-ru-a_SEP__': 'gn.np',
#  'lu2-dingir-ra-ta_SEP_Ludingira': 'pn.gen.abl.np',
#  'bi2-tum-ra-bi2-um_SEP__': 'pn.np',
#  'i3-ab-ru{ki}_SEP__': 'gn.np',
#  'ma-da{ki}-bi_SEP__': 'gn.np',
#  'hu-uh2-nu-ri{ki}_SEP_Huhnuri': 'sn.abs.np',
#  "szu-{d}iszkur_SEP_Szu'iszkur": 'pn.np',
#  '5(ban2)_SEP_5(ban)': 'n',
#  '4(disz)-kam_SEP_4(disz)': 'num.gen.cop-3-sg',
#  'nesag_SEP_Nesag': 'mn.l1.np',
#  '<us2>-sa_SEP_us': 'nf.vblex.pt',
#  'sza-asz-ru-um{ki}_SEP_Szaszrum': 'sn.abs.np',
#  "geme2-{d}ig-alim_SEP_Geme'igalim": 'pn.np',
#  'nam-mah_SEP_Nammah': 'pn.np',
#  'SIG7-a-ra_SEP_Sigara': 'pn.np',
#  'mar-tu_SEP_Martu': 'en.abs.np',
#  'lu2-nigin6{ki}-ke4_SEP_Lunigin': 'pn.gen.erg.np',
#  'inim_SEP_inim': 'n',
#  'in-ni-gar-ra_SEP_i-nn-i-n-gar': 'fin.3-sg-h.l2.3-sg-h-a.vblex.3-sg-p.sub',
#  'geme2-mu_SEP_geme': 'n.1-sg-poss.abs',
#  'ni_SEP_ni': 'n.abs',
#  'i3-me-a_SEP_i-me': 'fin.vblex.3-sg-s.sub',
#  'i3-bi2-za-asz_SEP_ibiza': 'n.term',
#  'e2-gal-e_SEP_egal': 'n.dat-nh',
#  'ma-ab-szum2-ma_SEP_mu-a-b-szum': 'ven.dat.3-sg-nh-p.vblex.3-sg-a.sub',
#  "gu3-de2-a_SEP_Gude'a": 'pn.np',
#  "ab-ba-iri_SEP_abba'iri": 'n',
#  'lu2-gir2-su{ki}_SEP_Lugirsu': 'pn.np',
#  'ur-x-da_SEP__': 'pn.np',
#  'kas4_SEP_kas': 'n.dat-h',
#  'maszkim-bi-me_SEP_maszkim': 'n.3-sg-nh-poss.abs.cop-3-pl.sub.abs',
#  'bi2-in-du11_SEP_b-i-n-dug': '3-sg-nh.l3.3-sg-h-a.vblex.3-sg-p',
#  'en3_SEP_en': 'n.abs',
#  'ba-ne-tar-ra_SEP_ba-nne-tar': 'mid.3-pl-dat.vblex.3-sg-s.sub',
#  'inim-bi_SEP_inim': 'n.3-sg-nh-poss.abs',
#  'nu-u3-zu_SEP_nu-i': 'neg.fin.3-sg-h-a.vblex.3-pl.sub.abs',
#  'bi2-in-ne2-sza-sze3_SEP_bi-i-n-e': '3-sg-nh.l2.3-sg-h-a.vblex.pl.3-pl.sub.gen.term',
#  'geme2_SEP_geme': 'n',
#  'lu2-gu2-gal_SEP_Lugugal': 'pn.np',
#  'lu2-{d}ba-ba6-ka_SEP_Lubaba': 'pn.gen.dat-h.np',
#  'ba-na-gi-in_SEP_ba-nn-a-gin': 'mid.3-sg-h.dat.vblex.3-sg-s',
#  'erin-da_SEP_Erinda': 'pn.abs.np',
#  'ur-{d}isztaran_SEP_Uristaran': 'pn.abs.np',
#  'di-ku5-bi-me_SEP_dikud': 'n.3-sg-nh-poss.abs.cop-3-pl',
#  'szagina_SEP_szakkanak': 'n',
#  'x_SEP__': 'n',
#  'mar-za_SEP_marza': 'n',
#  'ki-ba_SEP_ki': 'n.3-sg-nh-poss.l1',
#  'tusz-sza-me_SEP_tusz': 'nf.vblex.pt.abs.cop-3-pl',
#  '1(gesz2)_SEP_1(gesz)': 'num',
#  'a2-bi_SEP_a': 'n.3-sg-nh-poss.abs',
#  '8(szar2)_SEP_8(szar)': 'num.abs',
#  'tug2_SEP_tug': 'n',
#  'nig2-lam2_SEP_niglam': 'n.gen',
#  '3(disz)-kam_SEP_3(disz)': 'num.gen.cop-3-sg',
#  'us2_SEP_us': 'nf.vblex.abs',
#  'geme2-bi_SEP_geme': 'n.3-sg-nh-poss.abs',
#  '1/3(disz)-am3_SEP_1/3(disz)': 'num.abs.cop-3-sg',
#  'guz-za_SEP_guza': 'n.gen',
#  'sag_SEP_sag': 'n',
#  'usz-bar_SEP_uszbar': 'n',
#  '5/6(disz)-am3_SEP_5/6(disz)': 'num.abs.cop-3-sg',
#  'gada_SEP_gada': 'n',
#  '{gesz}tag_SEP_szerim': 'num',
#  'du3-a_SEP_du': 'nf.vblex.pt',
#  'ensi2-ta_SEP_ensik': 'n.gen.abl',
#  'hi-a_SEP_hi': 'nf.vblex.pt',
#  '2(u)-am3_SEP_2(u)': 'num.abs.cop-3-sg',
#  'kir11_SEP_kir': 'n',
#  'u3-tu-da_SEP__': 'pn.np',
#  'na-gab2-tum_SEP_nakabtum': 'n.gen.abs',
#  '{d}szul-gi-a-a-mu_SEP_Szulgirayamu': 'pn.erg.np',
#  'min3-kam_SEP__': 'num',
#  'tag-tag-ga_SEP__': 'nf.vblex.rdp.pt',
#  'udu-gi_SEP__': 'n.gen.gen.pl',
#  'szul-gi_SEP_Szulgir': 'rn.np',
#  "ki-en-gi_SEP_ki'engi": 'gn.np',
#  'ki-uri-ke4_SEP__': 'gn.gen.erg.np',
#  'hur-sag_SEP__': 'n',
#  'ki-ag2-ga2-ni_SEP__': 'nf.vblex.3-sg-h-poss.abs',
#  'mu-du3_SEP_mu': 'ven.3-sg-h-a.vblex.3-sg-p',
#  'gurum2-ak_SEP_gurum': 'n.gen',
#  'gu4-apin_SEP__': 'n',
#  'gub-ba_SEP_gub': 'nf.vblex.pt',
#  'gesz-e3-a_SEP__': 'n',
#  'szu-du8-a_SEP_': 'n.3-sg-h-poss.gen',
#  '{d}nin-{d}su4-an-na_SEP__': 'n.gen',
#  'dab5-ba_SEP_dab': 'n',
#  'x{ki}_SEP__': 'gn.np',
#  'a-de2_SEP__': 'vblex',
#  'gu4-sze3_SEP__': 'n',
#  'ha-la_SEP_Hala': 'pn.dat-h.np',
#  "ma2-dara3-abzu_SEP_Madara'abzu": 'on.np',
#  'in-dim2_SEP__': 'fin.3-sg-h.dat.3-sg-h-a.vblex.3-sg-p',
#  '{u2}gamun2_SEP__': 'n',
#  'ge6_SEP_giggi': 'nf.vblex.abs',
#  'gur-dub-bi_SEP__': 'n.abs',
#  '4(disz)-am3_SEP_4(disz)': 'num.abs.cop-3-sg',
#  "siki-ud5_SEP_siki'ud": 'n',
#  'gur-bi_SEP__': 'n.gen.3-sg-nh-poss.abs',
#  'sze-lu2_SEP__': 'n',
#  'dug-3(ban2)-bi_SEP__': 'num.3-sg-nh-poss.abs',
#  '2(disz)-am3_SEP_2(disz)': 'num.abs.cop-3-sg',
#  'dug-bi_SEP__': 'n.3-sg-nh-poss.abs',
#  '2(gesz2)_SEP_2(gesz)': 'num',
#  '3(disz)!_SEP_3(disz)': 'num',
#  '{kusz}ummu3_SEP_ummud': 'n',
#  '5(disz)-am3_SEP_5(disz)': 'num.gen.cop-3-sg',
#  'szabra-a_SEP__': 'pn.np',
#  'i3-szah2_SEP_iszah': 'n',
#  '4(disz)-ba_SEP_': 'num',
#  'bu-zu-a-ta_SEP__': 'pn.gen.abl.np',
#  'e2-kiszib3-ba-ka_SEP__': 'tn.np',
#  'ba-an-kux(KWU147)_SEP__': 'mid.l1-syn.vblex.3-sg-s',
#  'kar-gesztin-ka_SEP__': 'gn.np',
#  '2(esze3)_SEP_2(esze)': 'n',
#  'lugal-nig2-lagar-e_SEP_Lugalniglagare': 'pn.gen.np',
#  'gudu4_SEP_gudug': 'n',
#  '1/4(iku)_SEP_1/4(iku)': 'n',
#  'dam_SEP_dam': 'n',
#  '1(bur3)_SEP_1(bur)': 'n',
#  'ur-li-mu_SEP__': 'pn.np',
#  '8(asz)_SEP_8(asz)': 'num',
#  'n(esze3)_SEP__(esze)': 'n',
#  '3(iku)_SEP_3(iku)': 'n',
#  '4(iku)_SEP_4(iku)': 'n',
#  '1(esze3)_SEP_1(esze)': 'n',
#  '1(iku)_SEP_1(iku)': 'n',
#  'er3-mu_SEP__': 'pn.np',
#  '2(iku)_SEP_2(iku)': 'n',
#  '5(barig)_SEP_': 'num',
#  'gurx(|SZE.KIN|)_SEP__': 'nf.vblex.pt.gen',
#  'x-gibil_SEP__': 'fn.np',
#  '5(iku)_SEP_5(iku)': 'n',
#  '1/2(iku)_SEP_1/2(iku)': 'n',
#  'da-a-ga_SEP_': 'pn.np',
#  '2(asz)_SEP_2(asz)': 'num',
#  'lu2-du10-ga_SEP_Luduga': 'pn.np',
#  'igi-husz_SEP__': 'pn.np',
#  'in-zu-a_SEP__': 'vblex',
#  'igi-sze3_SEP_igi': 'n.term',
#  'ha-ba-lu5-ge2_SEP_Habaluge': 'pn.np',
#  'gaba_SEP_gaba': 'n',
#  'x-x-dingir_SEP__': 'dn.np',
#  'apin-la2-am3_SEP__': 'n.abs.cop-3-sg',
#  'n(iku)_SEP__(iku)': 'n',
#  'n(asz)_SEP__': 'n',
#  'gu4-suhub2_SEP_Gusuhub': 'fn.np',
#  'buru14_SEP__': 'n',
#  'a-pi4-sal4{ki}_SEP_Apisal': 'fn.l1.np',
#  'lugal-e_SEP_lugal': 'n.erg',
#  'ma2-gur8-mah_SEP_magurmah': 'n.abs',
#  '{d}en-lil2-x_SEP__': 'dn.np',
#  '{d}nin-lil2-ra_SEP_Ninlil': 'dn.dat-h.np',
#  'mu-ne-dim2_SEP_mu-nnee': 'ven.3-pl.dat.3-sg-h-a.vblex.3-sg-p',
#  '{gesz}tug2-gurx(|SZE.KIN|)_SEP_tuggur': 'n',
#  "lu2-igi-sa6-sa6-ta_SEP_Lu'igisasa": 'pn.gen.abl.np',
#  'na-ba-sa2_SEP_Nabasa': 'pn.erg.np',
#  'diri_SEP_dirig': 'n',
#  'ugu2-du6_SEP_Ugudu': 'pn.gen.np',
#  '{d}szara2_SEP_Szara': 'dn.np',
#  'lugal-ma2-gur8-re_SEP_Lugalmagure': 'pn.np',
#  'zabar-dab5_SEP_zabardab': 'n',
#  'szu-gid2_SEP_szugid': 'n',
#  'e2-muhaldim-sze3_SEP_emuhaldim': 'n.term',
#  'ezem-an-na_SEP_Ezemanna': 'mn.l1.np',
#  'limmu2-ba-ke4_SEP__': 'nf.vblex.3-sg-nh-poss.gen.erg',
#  'a2-bi2-a-bi-ih_SEP__': 'pn.np',
#  'sagi_SEP_sagi': 'n',
#  'ARAD2-da-ni-ir_SEP__': 'n.3-sg-h-poss.dat.h',
#  'in-na-ba_SEP__': 'fin.3-sg-h.dat.3-sg-h-a.vblex.3-sg-p',
#  'sar_SEP_sar': 'n',
#  'u2_SEP_u': 'n',
#  'sahar-ba_SEP_sahar': 'n.3-sg-nh-poss.gen',
#  'kab2-ku5_SEP_kabkul': 'n',
#  "a-u2-da-ta_SEP_A'uda": 'fn.gen.abl.np',
#  'u2-du-{d}nin-a-ra-li-sze3_SEP_Uduninarali': 'fn.gen.term.np',
#  'ki-BAD-ta_SEP_Kibad': 'fn.gen.abl.np',
#  'u3-sur_SEP_Usur': 'gn.np',
#  'tir-sze3_SEP_tir': 'n.gen.gen.term',
#  '5/6(disz)_SEP_5/6(disz)': 'num',
#  'kin_SEP_kig': 'n',
#  'sahar_SEP_sahar': 'n.gen',
#  '{d}nin-hur-sag-ka_SEP_Ninhursag': 'dn.gen.l1.np',
#  'engar_SEP_engar': 'n',
#  'nu-banda3-gu4_SEP_nubandagu': 'n',
#  'sza3-sahar_SEP_szagsahar': 'n.gen.gen',
#  'e_SEP_eg': 'n',
#  'sa-dur2-ra_SEP_sadurra': 'n',
#  'u3-wa-ri-da_SEP_Uwarida': 'wn.l1.np',
#  'iszib-e-ne_SEP_Iszibene': 'fn.gen.gen.l1.np',
#  '8(gesz2)_SEP_8(gesz2)': 'num',
#  'da-da_SEP_Dada': 'pn.np',
#  'an-sza-an{ki}_SEP_Anszan': 'gn.abs.np',
#  'na-ni_SEP_Nani': 'pn.np',
#  'ur5-ra_SEP_urra': 'n',
#  'lugal-me-lam2_SEP_Lugalmelam': 'pn.np',
#  'ur-ma-ma_SEP_Urmama': 'pn.gen.np',
#  'in-na-szum2-ma_SEP_i-nn-a': 'fin.3-sg-h.dat.3-sg-h-a.vblex.3-sg-p.sub.l1',
#  '{u2}har-an_SEP_haran': 'n',
#  'kab2-ku5-a_SEP_kabkul': 'n.l1.term',
#  'de2-a_SEP_de': 'nf.vblex.pt',
#  'u2-du-{d}nin-a-ra-li-ka_SEP_Uduninarali': 'pn.gen.gen.np',
#  'ur-{d}da-mu_SEP_Urdamu': 'pn.np',
#  'inim-{d}inanna_SEP_Iniminanna': 'pn.np',
#  'szu-{d}idim-ta_SEP__': 'pn.gen.gen.abl.np',
#  'ezem-{d}nin-a-zu_SEP_Ezemninazu': 'mn.l1.np',
#  'lu-lu-bu{ki}_SEP_Lulubu': 'sn.abs.np',
#  '1(disz@t)-kam_SEP_1(disz)': 'num.gen.cop-3-sg',
#  'dusu2-nita2_SEP__': 'pn.np',
#  'dusu2-munus_SEP__': 'n',
#  'ziz2_SEP_ziz': 'n',
#  '...{ki}_SEP__': 'sn.abs.np',
#  'mah_SEP_mah': 'nf.vblex',
#  'mu-ne-du3_SEP_mu-nnee': 'ven.3-pl.dat.3-sg-h-a.vblex.3-sg-p',
#  'na-wi-ir-dingir_SEP__': 'pn.np',
#  'i3-du8_SEP_idu': 'n.gen.abs',
#  'a-na-a_SEP__': 'pn.np',
#  'lukur-a-ni_SEP__': 'pn.np',
#  'sag-nig2-gur11-e_SEP_': 'pn.np',
#  'en-te_SEP__': 'pn.np',
#  'min-na-sze3_SEP__': 'mn.term.np',
#  'ur-{d}da-mu-ta_SEP__': 'pn.gen.abl.np',
#  'ur-ga2-gi4-a_SEP__': 'pn.np',
#  'ba-ti-esz2_SEP_ba': 'mid.3-sg-h-a.vblex.3-pl',
#  'bara2-za3-gar_SEP__': 'mn.np',
#  'zal-la_SEP_zal': 'nf.vblex.pt',
#  'a-bu-ni_SEP_Abuni': 'pn.gen.np',
#  'lu2_SEP_zah': 'nf.vblex.pt',
#  'zah3_SEP_': 'vblex',
#  'dab5-de3_SEP_gen': 'nf.vblex.pt',
#  "i3-udu_SEP_i'udu": 'n',
#  'i-di3-zu_SEP_': 'pn.np',
#  '{gesz}tukul-gu-la_SEP_tukulgal': 'n.dat-h',
#  '<ninda>_SEP_ninda': 'n',
#  "szu-er3-ra_SEP_Szu'era": 'pn.np',
#  "sze-il2-la_SEP_Sze'ila": 'mn.l1.np',
#  'sza3-tam_SEP_': 'n.abs',
#  'a-gu-gu_SEP_Agugu': 'pn.gen.np',
#  'lugal-ku3-ga-ni_SEP_Lugalkugani': 'pn.gen.np',
#  'si-i3-tum_SEP_situm': 'n',
#  'nigin6_SEP__': 'n',
#  "me-{d}isztaran_SEP_Me'isztaran": 'pn.np',
#  'nin9_SEP__': 'n',
#  '{d}iszkur-illat_SEP__': 'pn.np',
#  'a-bi2-a_SEP__': 'pn.np',
#  'didli_SEP_didli': 'nf.vblex.abs',
#  'masz-x-x_SEP__': 'pn.np',
#  'lu2-gi-na-ta_SEP_Lugina': 'pn.gen.abl.np',
#  'de6-a_SEP_de': 'nf.vblex.pt',
#  'am_SEP_am': 'n',
#  'amar_SEP_amar': 'n',
#  'pesz_SEP_pesz': 'n.abs',
#  "szu-esz5-sza_SEP_Szu'eszsza": 'mn.l1.np',
#  'a-gu_SEP_Agu': 'pn.np',
#  'gaszam_SEP__': 'n',
#  'szabra_SEP_szabra': 'n',
#  'ib2-dab5_SEP_': 'vblex',
#  'kuruszda-e_SEP__': 'n.3-sg-h-poss.dat-h',
#  '{kusz}du10-gan-na_SEP_duggan': 'n.gen.l1',
#  'masz-da3-gu7-ta_SEP_Maszdagu': 'mn.abl.np',
#  'sze-sag11-ku5-sze3_SEP_Szesagku': 'mn.term.np',
#  'hu-uh2-<nu>-ri{ki}_SEP_Huhnuri': 'sn.abs.np',
#  'u4-da_SEP_ud': 'n',
#  'e2-gal_SEP_egal': 'n',
#  'siskur2_SEP_siszkur': 'n',
#  'hi-ba-ri2-tum{ki}_SEP_Hibaritum': 'sn.gen.gen.np',
#  'min-esz3_SEP_Minesz': 'mn.l1.np',
#  '{d}ga2-tum3-du10_SEP__': 'dn.np',
#  'ses-da-gu7_SEP_Sesdagu': 'mn.l1.np',
#  'sza-asz-ru{ki}_SEP_Szaszru': 'sn.abs.np',
#  "in-ta-e3-a_SEP_Inta'e'a": 'pn.erg.np',
#  'gu-du-du-ta_SEP__': 'pn.gen.abl.np',
#  'umma{ki}-ka_SEP_Umma': 'sn.gen.gen.abs.np',
#  'lugal-e2-mah-e_SEP_Lugalemahe': 'pn.np',
#  'duh_SEP_duh': 'n',
#  'nig2-ar3-ra_SEP_nigara': 'n',
#  'dabin_SEP_dabin': 'n',
#  '8(disz)-kam_SEP_8(disz)': 'num.gen.cop-3-sg',
#  'mu-sza_SEP__': 'pn.np',
#  'e2-kiszib3-ba-ta!_SEP__': 'tn.np',
#  'lu2-{d}suen_SEP_Lusuen': 'pn.np',
#  'ur-sa6!-ga_SEP_Ursaga': 'pn.np',
#  'sipa_SEP_sipa': 'n',
#  'lu2-{d}ig-alim_SEP__': 'pn.np',
#  'ur-ki-gu-la_SEP__': 'pn.gen.abs.np',
#  'sza3-tam-e-ne_SEP__': 'pn.np',
#  '1(disz)-ta_SEP_1(disz)': 'num.abl',
#  '$)-kam_SEP__': 'n',
#  'mu-ri-iq-ti-id-ni-im_SEP_Muriqtidnim': 'on.abs.np',
#  "ki-uri_SEP_ki'uri": 'gn.gen.np',
#  'ki-lu5-la-ta_SEP_Kilula': 'pn.gen.abl.np',
#  'ma-an-ba-ta_SEP_Manba': 'pn.gen.abl.np',
#  'nigar{gar}-ki-du10-ta_SEP_Nigarkidu': 'pn.gen.abl.np',
#  'a-kal-la-ta_SEP_Akala': 'pn.gen.abl.np',
#  'sag-nig2-gur11-ra_SEP_sagnigGArak': 'n',
#  'nu-banda3_SEP_nubanda': 'n',
#  'gu4-ke4-ne_SEP__': 'n.gen.pl',
#  'mu-dim2_SEP_': 'ven.3-sg-h-a.vblex.3-sg-p',
#  'gin-a_SEP__': 'n',
#  '2(ban2)-ta_SEP__': 'num',
#  '5(disz)-ta_SEP_': 'num.abl',
#  'gin2-ta_SEP_gig': 'n.abl',
#  'masz-ku3-gu7_SEP_Maszkugu': 'mn.l1.np',
#  'u5-bi2{muszen}-gu7_SEP_Ubigu': 'mn.l1.np',
#  'ki-siki-{d}nin-a-zu_SEP_Kisikininazu': 'mn.l1.np',
#  'ma-na-ta_SEP__': 'n',
#  'har_SEP__': 'n',
#  'giri17_SEP__': 'n',
#  'ezem_SEP_ezem': 'n',
#  'szu-numun-na-sze3_SEP__': 'n',
#  'diri!_SEP_diri': 'n',
#  '{d}nanna-dalla_SEP__': 'dn.np',
#  'e2-gal-la_SEP_egal': 'n.l1',
#  'kux(KWU636)-ra_SEP__': 'nf.vblex.pt',
#  'nu-ur2!-..._SEP_': 'pn.np',
#  'szu-e2-a_SEP_Szuea': 'pn.np',
#  'an-na-sze3_SEP_An': 'dn.gen.term.np',
#  'dam-gar3-ne_SEP__': 'vblex',
#  'masz-ku3-gu7-ta_SEP__': 'mn.gen.abl.np',
#  'ezem-mah-sze3_SEP__': 'n',
#  'iti-bi_SEP_iti': 'n.3-sg-nh-poss.abs',
#  'bad3-gal-bi_SEP_badgal': 'n.dem2.abs',
#  'ur-{d}namma_SEP_Urnamma': 'rn.np',
#  '{d}en-lil2-la2_SEP_Enlil': 'dn.gen.np',
#  'in-du3-a_SEP_i-n-du': 'fin.3-sg-h-a.vblex.3-sg-p.sub.abs',
#  'gibil-sze3_SEP__': 'nf.vblex.abs.term',
#  'en-dingir-mu_SEP_Endingirmu': 'pn.np',
#  'a-mur-{d}suen_SEP__': 'pn.np',
#  'szesz-a-ni_SEP_Szeszani': 'pn.np',
#  'ra2-gaba_SEP_ragaba': 'n.abs',
#  'en-mah-gal-an-na_SEP_Enmahgalana': 'pn.np',
#  '{d}lamma_SEP__': 'n',
#  'tar-sir2-sir2-ra_SEP__': 'sn.gen.np',
#  'ama_SEP__': 'n',
#  '{d}ba-ba6_SEP__': 'dn.np',
#  'nin-a-ni_SEP_nin': 'n.3-sg-h-poss.dat-h',
#  "ki-en-<gi>_SEP_ki'engi": 'gn.np',
#  'ki-uri-ka-sze3_SEP__': 'gn.gen.gen.term.np',
#  'ha-la-{d}lamma_SEP__': 'pn.np',
#  'lagasz{ki}-ka-ke4_SEP__': 'sn.gen.gen.erg.np',
#  'e-la-ak-szu-qir-ra_SEP__': 'pn.gen.abl.np',
#  'he2-na-ab-szum2-mu_SEP_ha-i-nn-a-b-szum': 'mod.fin.3-sg-h.dat.3-sg-nh-p.vblex.3-sg-a',
#  'na-mi-gur-re_SEP_nan-m': 'mod.ven.3-sg-nh.l2.3-sg-nh-p.vblex.3-sg-a',
#  'gu2-na-kam_SEP__': 'pn.np',
#  'tukum-bi_SEP_tukumbi': 'cnjcoo',
#  'nu-na-an-szum2_SEP__': 'vblex',
#  'e2-a-ni-ta_SEP__': 'pn.gen.abl.np',
#  'ib2-su-su_SEP__': 'pn.np',
#  'ARAD2-{d}nanna_SEP_Aradnanna': 'pn.np',
#  'ka-guru7_SEP_kaguruk': 'n',
#  'ur-{d}nansze-ta_SEP_Urnansze': 'pn.gen.abl.np',
#  'szul-e2-du3-du3-e_SEP_Szuledudu': 'pn.erg.np',
#  'gu4-ra2-bi2-mu2-mu2_SEP_Gurabimumu': 'mn.l1.np',
#  'an-sza{ki}_SEP_Anszan': 'gn.abs.np',
#  'szul-e2-du3-du3_SEP_Szuledudu': 'pn.gen.np',
#  'ba-..._SEP__': 'pn.gen.np',
#  '{d}utu-..._SEP__': 'pn.dat-h.np',
#  '...-x-al-x-..._SEP__': 'pn.np',
#  'lu2-{d}x_SEP__': 'pn.np',
#  's,a-al-li2-a_SEP__': 'pn.np',
#  'ur-{d}ba-ba6_SEP_Urbaba': 'pn.np',
#  'i3!_SEP_i': 'n',
#  'hu-la-ni-a_SEP__': 'pn.gen.abs.np',
#  'ha-ab-lu-lu_SEP__': 'pn.np',
#  'suhusz-gi_SEP__': 'pn.np',
#  'szu-{d}inanna_SEP__': 'pn.np',
#  'sza3-mu_SEP__': 'pn.np',
#  '{d}li9-si4_SEP_Lisi': 'mn.l1.np',
#  'si-ma-num2{ki}_SEP_Simanum': 'sn.abs.np',
#  'gaba-ri_SEP_gabari': 'n',
#  'kiszib3-ba_SEP_kiszibba': 'n',
#  'siki_SEP_siki': 'n',
#  'ku4-ra_SEP_kur': 'nf.vblex.pt',
#  '{d}utu-GIR2@g-gal_SEP_UtuGIRgal': 'pn.np',
#  'ba-du3-sze3_SEP__': 'vblex',
#  'gu2-na_SEP_gun': 'n.gen',
#  'i3-la-...-ta_SEP__': 'pn.gen.abl.np',
#  'PA_SEP_ugula': 'n.abs',
#  '{d}szu-{d}suen-e_SEP_Szusuen': 'rn.erg.np',
#  'na-mah_SEP_namah': 'n.abs',
#  'a2-zi-da_SEP_Azida': 'pn.dat-h.np',
#  'ur-{d}nin-urta_SEP__': 'pn.np',
#  'lugal-nam-tar-re-ta_SEP__': 'pn.gen.abl.np',
#  'ama-bi_SEP__': 'n',
#  'gi4-gi4_SEP__': 'vblex',
#  'a-sza3-mu_SEP__': 'n.gen',
#  'a-e_SEP__': 'n',
#  'ba-ab-rex(HU)_SEP__': 'mid.3-sg-h-a.vblex.3-pl',
#  'u4-de3_SEP_': 'n.l3-nh',
#  'nu-ub-be2-ne-a_SEP__': 'pn.np',
#  'lugal-ra_SEP__': 'n',
#  'sanga_SEP_sagga': 'n',
#  'nu-na-be2-ne-a_SEP__': 'nf.vblex.sub',
#  'lugal-bi_SEP__': 'n',
#  'i3-pa3-de3-esz2_SEP__': 'fin.3-sg-h-a.vblex.3-pl',
#  'en-am-gal_SEP_Enamgalanna': 'pn.np',
#  'masz2-e_SEP_masz': 'n.l3-nh',
#  'lu2-{d}lamma_SEP__': 'pn.np',
#  'nigin-ba_SEP__': 'n.dem2.gen',
#  'siki-ba_SEP__': 'vblex',
#  'gir2-su{ki}-ta_SEP_Girsu': 'sn.gen.gen.abl.np',
#  'gu2-ab-ba{ki}-sze3_SEP__': 'sn.gen.gen.term.np',
#  'x-ri-ni{ki}_SEP__': 'gn.np',
#  'szi-pa-ra{ki}_SEP__': 'gn.abs.np',
#  'mu-x_SEP_': 'pn.dat-h.np',
#  'szi-masz-gi5{ki}_SEP__': 'gn.np',
#  'sa-bu-um{ki}_SEP__': 'sn.np',
#  'bi-da-..._SEP__': 'pn.np',
#  'du8-du8-li2{ki}_SEP__': 'gn.np',
#  "'._SEP_": 'n',
#  'an-sza4-an{ki}_SEP__': 'sn.np',
#  'unu{ki}_SEP_Unug': 'sn.gen.l1.np',
#  'ur5-sze3_SEP_urra': 'n.term',
#  'nu-tuku_SEP_nu-tuku': 'neg.nf.vblex.pt',
#  'lugal-a2-zi-da-ta_SEP_Lugalazida': 'pn.gen.abl.np',
#  'sig4-ga-ka_SEP_Siga': 'mn.l1.np',
#  'su-su-dam_SEP_sug-sug': 'nf.vblex.rdp.f.abs.cop-3-sg',
#  'ARAD2-dam_SEP_Aradam': 'pn.abs.np',
#  "lu2-inim-ma-bi-me_SEP_lu'inimak": 'n.3-sg-nh-poss.abs.cop-3-pl',
#  "apin-du8-a_SEP_Apindu'a": 'mn.abl.np',
#  'ba-zal_SEP_ba-zal': 'mid.vblex.3-sg-s.sub',
#  'us2-a_SEP_us': 'nf.vblex.pt',
#  'lugal-engar-du10_SEP_Lugalengardu': 'pn.gen.np',
#  'dub_SEP_dub': 'n',
#  'lugal-a-ma-ru_SEP__': 'pn.dat-h.np',
#  'dida_SEP_dida': 'n',
#  'la-ma-mu_SEP_Lamamu': 'pn.dat-h.np',
#  '{d}utu-mu_SEP_Utumu': 'pn.dat-h.np',
#  "e2-iti-6(disz)_SEP_E'iti6": 'mn.l1.np',
#  'hu-uh2_SEP_Huh': 'sn.np',
#  'ur-e2-an-na_SEP__': 'pn.np',
#  '{uruda}ha-bu3-da_SEP_habuda': 'n',
#  'ki-la2-bi_SEP_kila': 'n.3-sg-nh-poss.abs',
#  'da-da-ga-ta_SEP_Dadaga': 'pn.gen.abl.np',
#  'ensi2-ke4_SEP_ensik': 'n.erg',
#  'in-la2_SEP_i-n-la': 'fin.3-sg-h-a.vblex.3-sg-p',
#  'szu-numun_SEP_Szunumun': 'mn.l1.np',
#  'us2-sa-bi_SEP_us': 'nf.vblex.pt.3-sg-nh-poss',
#  'GAN2-gu4_SEP_GANAgud': 'fn.gen.np',
#  'apin-la2_SEP_apinla': 'n',
#  'kux(KWU147)-kux(KWU147)_SEP__': 'nf.vblex.pt',
#  'szuku-sze3_SEP__': 'n',
#  'ha-la-a_SEP__': 'pn.gen.gen.np',
#  'nig2-ka9_SEP_nigSZID': 'n',
#  'szi-im_SEP__': 'n',
#  'didli-bi_SEP_': 'nf.vblex.3-sg-nh-poss.abs',
#  '{d}gu-la_SEP_Gula': 'dn.np',
#  '{d}nansze-GIR2@g-gal_SEP__': 'pn.np',
#  'na-lu5_SEP_Nalu': 'pn.erg.np',
#  'lu2-saga_SEP_Lusaga': 'pn.erg.np',
#  'ha-ba-mu_SEP__': 'pn.np',
#  'i3-li2-a_SEP__': 'pn.np',
#  'ur-szu_SEP__': 'pn.np',
#  'muhaldim_SEP__': 'n',
#  'ri-im-i3-li2_SEP__': 'pn.abs.np',
#  'ab-ba-kal-la_SEP_Abbakala': 'pn.np',
#  'lu2-{d}nin-gir2-su_SEP_Luningirsu': 'pn.np',
#  'id-gur2_SEP_idgurum': 'n',
#  "a-hu-a-ga_SEP_Ahu'aga": 'pn.np',
#  'sa-gaz-ak-sze3_SEP_Sagazak': 'sn.term.np',
#  'gen-na_SEP_gen': 'nf.vblex.pt',
#  'KA_SEP_ka': 'n',
#  'inim-ma-ta_SEP_inim': 'n.gen.abl',
#  'KA-a-sze3_SEP_Kaya': 'sn.term.np',
#  'an-sza-an{ki}-ta_SEP_Anszan': 'gn.abl.np',
#  'nibru{ki}-ta_SEP_Nibru': 'sn.abl.np',
#  'nig2-dab5-ke4-ne_SEP__': 'n.gen.pl',
#  'x-x-ke4-ne_SEP_': 'dn.np',
#  'ma-ni_SEP__': 'n.3-sg-h-poss',
#  'szah2_SEP_szah': 'n',
#  'ama-gan_SEP_amagan': 'n',
#  'szah2-nita2_SEP_szahnita': 'n',
#  'szah2-NE-tur_SEP_zahda': 'n',
#  'szu-kab-ta-sze3_SEP_Szukabta': 'pn.gen.term.np',
#  'ba-sa6-ga_SEP_Basaga': 'pn.np',
#  'zi-ga-am3_SEP_zig': 'nf.vblex.pt.abs.cop-3-sg',
#  'nig2-gur11_SEP_nigGA': 'n',
#  'sze-le2-pu-tum_SEP_Szeleputum': 'pn.np',
#  'dumu-munus_SEP_dumumunus': 'n',
#  'nu-hi-dingir_SEP_Nuhidingir': 'pn.np',
#  'ba-a-ga_SEP_Bayaga': 'pn.np',
#  'kuruszda_SEP_kuruszda': 'n.gen.abs',
#  '3(u)-sze3_SEP_3(u)': 'num.term',
#  'lugal-igi_SEP__': 'pn.np',
#  'dumu-da-ba_SEP__': 'n',
#  'ug3-IL2_SEP_uggaga': 'n',
#  'ur-{d}gesz-bar-e3_SEP__': 'pn.erg.np',
#  ...}

# %% [markdown]
# ## Preparing skeleton of Sux vocab and the dictionary

# %% [markdown]
# ### Sux vocab

# %%
# sumerian vocab
sux_morph_name = '../apertium-sux/apertium-sux.sux.lexd'
with open(sux_morph_name,'w') as f:
    f.write("# Morphological Transducer for Sumerian \n")

# %%
s = ''' \n\n
# =========================================================

# 1. Verb

PATTERNS 
VerbRoot


# =========================================================

# 2. Noun

PATTERNS 
NounRoot



# =========================================================

# 3. Named Entity PATTERNS

PATTERNS 
Named_Entities



# =========================================================

# 4. Numbers

PATTERNS 
Numbers


# =========================================================

# 5. Coordinative Conjugations

PATTERNS 
Conjugation








###############################################################################
###                          L E X I C O N                                  ###
###############################################################################

'''
txt_file_write(sux_morph_name,[s])

# %% [markdown]
# ### Sux-Eng bi-dict

# %%
# sumerian english bilingual dictionary
sux_eng_dict_name = 'apertium-sux-eng.sux-eng.dix'
with open(sux_eng_dict_name,'w') as f:
    f.write("<?xml version='1.0' encoding='us-ascii'?> \n")

# %%
# start dictionary
l = ['<dictionary>']
txt_file_write(sux_eng_dict_name,l)

# %%
# put all the tags
s = ''' <sdefs>
    <sdef n="n" 	c="Noun"/>
    <sdef n="np" 	c="Proper name"/>
    <sdef n="pr" 	c="Preposition"/>
    <sdef n="vblex" 	c="Verb"/>
    <sdef n="vbmod" 	c="Modal verb"/>
    <sdef n="vaux" 	c="Auxiliary verb"/>
    <sdef n="vbser" 	c="Verb to be"/>
    <sdef n="vbhaver" 	c="Verb to have"/>
    <sdef n="vbdo" 	c="Verb to do"/>
    <sdef n="det" 	c="Determiner"/>
    <sdef n="predet" 	c="Predeterminer"/>
    <sdef n="prn" 	c="Pronoun"/>
    <sdef n="cnjcoo" 	c="Coordinating conjunction"/>
    <sdef n="cnjsub" 	c="Subordinating conjunction"/>
    <sdef n="p1" 	c="First person"/>
    <sdef n="p2" 	c="Second person"/>
    <sdef n="p3" 	c="Third person"/>
    <sdef n="attr" 	c="Attributive"/>
    <sdef n="sg" 	c="Singular"/>
    <sdef n="pl" 	c="Plural"/>
    <sdef n="sp" 	c="Singular / plural"/>
    <sdef n="m" 	c="Masculine"/>
    <sdef n="f" 	c="Feminine"/>
    <sdef n="mf" 	c="Masculine / feminine"/>
    <sdef n="nt" 	c="Neuter"/>
    <sdef n="mfn" 	c="Masculine / feminine / neuter"/>
    <sdef n="def" 	c="Definite"/>
    <sdef n="ind" 	c="Indefinite"/>
    <sdef n="ref" 	c="Reflexive"/>
    <sdef n="dem" 	c="Demonstrative"/>
    <sdef n="top" 	c="Toponym"/>
    <sdef n="al" 	c="Altres (other)"/>
    <sdef n="ant" 	c="Anthroponym (first name)"/>
    <sdef n="cog" 	c="Cognomen (family name)"/>
    <sdef n="prs" 	c="Present subjunctive"/>
    <sdef n="pres" 	c="Present (tense)"/>
    <sdef n="past" 	c="Past"/>
    <sdef n="pii" 	c="Past indicative"/>
    <sdef n="pis" 	c="Past subjunctive"/>
    <sdef n="imp" 	c="Imperative"/>
    <sdef n="inf" 	c="Infinitive"/>
    <sdef n="pp" 	c="Past participle"/>
    <sdef n="subs" 	c="Verbal noun"/>
    <sdef n="pprs" 	c="Present participle"/>
    <sdef n="ger" 	c="Gerund"/>
    <sdef n="cm" 	c="Comma"/>
    <sdef n="sent" 	c="End of sentence marker"/>
    <sdef n="quot" 	c="Quote mark"/>
    <sdef n="lquot" 	c="Quote mark left"/>
    <sdef n="rquot" 	c="Quote mark right"/>
    <sdef n="abbr" 	c="Abbreviation"/>
    <sdef n="adj" 	c="Adjective"/>
    <sdef n="adv" 	c="Adverb"/>
    <sdef n="preadv" 	c="Pre-adverb"/>
    <sdef n="rel" 	c="Relative"/>
    <sdef n="itg" 	c="Interrogative"/>
    <sdef n="cnjadv" 	c="Adverbial conjunction"/>
    <sdef n="comp" 	c="Comparative"/>
    <sdef n="sup" 	c="Superlative"/>
    <sdef n="pred" 	c="Predicative"/>
    <sdef n="ord" 	c="Ordinal"/>
    <sdef n="qnt" 	c="Quantifier"/>
    <sdef n="num" 	c="Numeral / Number"/>
    <sdef n="pron" 	c="Pronoun"/>
    <sdef n="ij" 	c="Interjection"/>
    <sdef n="lpar" 	c="Left parenthesis"/>
    <sdef n="rpar" 	c="Right parenthesis"/>
    <sdef n="apos" 	c="Apostrophe"/>
    <sdef n="percent" 	c="Percentage"/>
    <sdef n="guio" 	c="Hyphen"/>
    <sdef n="sep" 	c="Seperable verb"/>
    <sdef n="sint" 	c="Synthetic adjective"/>
    <sdef n="nom" 	c="Nominative"/>
    <sdef n="gen" 	c="Genitive"/>
    <sdef n="acr" 	c="Acronym"/>
    <sdef n="org" 	c="Organisation"/>
    <sdef n="tn" 	c=""/>
    <sdef n="nn" 	c=""/>
    <sdef n="aa" 	c="Animate"/>
    <sdef n="an" 	c="Inanimate"/>
    <sdef n="pos" 	c="Possessive"/>
    <sdef n="lquest" 	c="left question mark"/>
    <sdef n="obj" 	c="Object"/>
    <sdef n="subj" 	c="Subject"/>
    <sdef n="pers" 	c="Personal (pronoun)"/>
    <sdef n="file" 	c="Filename"/>
    <sdef n="l3" c="l3"/>
<sdef n="mn" c="mn"/>
<sdef n="fn" c="fn"/>
<sdef n="abl" c="abl"/>
<sdef n="nh" c="nh"/>
<sdef n="sn" c="sn"/>
<sdef n="en" c="en"/>
<sdef n="on" c="on"/>
<sdef n="pt" c="pt"/>
<sdef n="ven" c="ven"/>
<sdef n="gn" c="gn"/>
<sdef n="mod" c="mod"/>
<sdef n="ak" c="ak"/>
<sdef n="pn" c="pn"/>
<sdef n="dah" c="dah"/>
<sdef n="h" c="h"/>
<sdef n="wn" c="wn"/>
<sdef n="rn" c="rn"/>
<sdef n="hn" c="hn"/>
<sdef n="nf" c="nf"/>
<sdef n="pf" c="pf"/>
<sdef n="abs" c="abs"/>
<sdef n="dem2" c="dem2"/>
<sdef n="fin" c="fin"/>
<sdef n="poss" c="poss"/>
<sdef n="rdp" c="rdp"/>
<sdef n="neg" c="neg"/>
<sdef n="l2" c="l2"/>
<sdef n="dat" c="dat"/>
<sdef n="None" c="None"/>
<sdef n="l1" c="l1"/>
<sdef n="mid" c="mid"/>
<sdef n="com" c="com"/>
<sdef n="cop" c="cop"/>
<sdef n="erg" c="erg"/>
<sdef n="term" c="term"/>
<sdef n="sub" c="sub"/>
<sdef n="syn" c="syn"/>
<sdef n="dn" c="dn"/>
</sdefs> '''

# start dictionary
l = [s]
txt_file_write(sux_eng_dict_name,l)

# %%
# start main section
l = ['\n <section id="main" type="standard">']
txt_file_write(sux_eng_dict_name,l)

# %% [markdown]
# # Working based on POS TAGS
# ### np(Named Entity), num(numbers), cnjcoo, n, vblex

# %%
# most_freq_tags

# %% [markdown]
# ## Named Entity, Numbers, Cnjcoo, Noun, Verb

# %%
NE_sux = '''\n'''
NE_dict = '''\n'''

Num_sux = '''\n'''
Num_dict = '''\n'''

Cnjcoo_sux = '''\n'''
Cnjcoo_dict = '''\n'''

N_sux = '''\n'''
N_dict = '''\n'''

V_sux = '''\n'''
V_dict = '''\n'''



for key, val in most_freq_tags.items():
    form,lemma = key.split('_SEP_')
    form = form.replace(':','-').replace('{','\{').replace('}','\}').replace('[','\[').replace(']','\]')\
        .replace('(','\(').replace(')','\)').replace('|','\|').replace('<','').replace('>','').replace('@','').replace('.','') # to escape the special meaning of brackets
    bi_dict_key = re.sub('[^a-zA-Z0-9]+','_',key)
    eng_translation = most_freq_translation[key].replace('’','').replace('\'','')
    p_tag = val.split('.')



    # check if there is somthing in form or not
    if len(form)<2:
        continue



    # for named entity
    if 'np' in p_tag:
        remainig_tags = list(set(p_tag)-set(['np']))
        pos_tag = 'np'
        tg_str = '<np>'
        for t in remainig_tags:
            tg_str+='<'+t+'>'

        # for morph dict
        sux_morph = bi_dict_key+tg_str+':'+form

        # for translation dict
        sux_eng_dict = f'''<e><p><l>{bi_dict_key}<s n="{pos_tag}"/></l><r>{eng_translation}<s n="{pos_tag}"/></r></p></e>'''
        
        NE_sux+=sux_morph+"\n"
        NE_dict+=sux_eng_dict+"\n"

    
    
    # for numbers
    if 'num' in p_tag:
        remainig_tags = list(set(p_tag)-set(['num']))
        pos_tag = 'num'
        tg_str = '<num>'
        for t in remainig_tags:
            tg_str+='<'+t+'>'

        # for morph dict
        sux_morph = bi_dict_key+tg_str+':'+form

        # for translation dict
        sux_eng_dict = f'''<e><p><l>{bi_dict_key}<s n="{pos_tag}"/></l><r>{eng_translation}<s n="{pos_tag}"/></r></p></e>'''
        
        Num_sux+=sux_morph+"\n"
        Num_dict+=sux_eng_dict+"\n"



    # for conjugation
    if 'cnjcoo' in p_tag:
        remainig_tags = list(set(p_tag)-set(['cnjcoo']))
        pos_tag = 'cnjcoo'
        tg_str = '<cnjcoo>'
        for t in remainig_tags:
            tg_str+='<'+t+'>'

        # for morph dict
        sux_morph = bi_dict_key+tg_str+':'+form

        # for translation dict
        sux_eng_dict = f'''<e><p><l>{bi_dict_key}<s n="{pos_tag}"/></l><r>{eng_translation}<s n="{pos_tag}"/></r></p></e>'''
        
        Cnjcoo_sux+=sux_morph+"\n"
        Cnjcoo_dict+=sux_eng_dict+"\n"



    # for nouns
    if 'n' in p_tag:
        remainig_tags = list(set(p_tag)-set(['n']))
        pos_tag = 'n'
        tg_str = '<n>'
        for t in remainig_tags:
            tg_str+='<'+t+'>'

        # for morph dict
        sux_morph = bi_dict_key+tg_str+':'+form

        # for translation dict
        sux_eng_dict = f'''<e><p><l>{bi_dict_key}<s n="{pos_tag}"/></l><r>{eng_translation}<s n="{pos_tag}"/></r></p></e>'''
        

        N_sux+=sux_morph+"\n"
        N_dict+=sux_eng_dict+"\n"


    # for verbs
    if 'vblex' in p_tag:
        remainig_tags = list(set(p_tag)-set(['vblex']))
        pos_tag = 'vblex'
        tg_str = '<vblex>'
        for t in remainig_tags:
            tg_str+='<'+t+'>'

        # for morph dict
        sux_morph = bi_dict_key+tg_str+':'+form

        # for translation dict
        sux_eng_dict = f'''<e><p><l>{bi_dict_key}<s n="{pos_tag}"/></l><r>{eng_translation}<s n="{pos_tag}"/></r></p></e>'''
        
        V_sux+=sux_morph+"\n"
        V_dict+=sux_eng_dict+"\n"

# %% [markdown]
# ## Writing data to sux morphdict

# %%
s = '''





#=============================================================
LEXICON VerbRoot
'''
l = [s, V_sux]
txt_file_write(sux_morph_name,l)

# %%
s = '''





#=============================================================
LEXICON NounRoot
'''
l = [s, N_sux]
txt_file_write(sux_morph_name,l)

# %%
s = '''





#=============================================================
LEXICON Named_Entities
'''
l = [s, NE_sux]
txt_file_write(sux_morph_name,l)

# %%
s = '''






#=============================================================
LEXICON Numbers
'''
l = [s, Num_sux]
txt_file_write(sux_morph_name,l)

# %%
s = '''






#=============================================================
LEXICON Conjugation
'''
l = [s, Cnjcoo_sux]
txt_file_write(sux_morph_name,l)

# %% [markdown]
# ## Writing data to bilingual dict

# %%
s = '''



<!-- Verbs -->
'''
l = [s, V_dict]
txt_file_write(sux_eng_dict_name,l)

# %%
s = '''



<!-- Noun -->
'''
l = [s, N_dict]
txt_file_write(sux_eng_dict_name,l)

# %%
s = '''



<!-- Named_Entity -->
'''
l = [s, NE_dict]
txt_file_write(sux_eng_dict_name,l)

# %%
s = '''



<!-- Numbers -->
'''
l = [s, Num_dict]
txt_file_write(sux_eng_dict_name,l)

# %%
s = '''



<!-- Conjugation -->
'''
l = [s, Cnjcoo_dict]
txt_file_write(sux_eng_dict_name,l)

# %%
# ending dict and main section
l = ['''\n </section>
</dictionary>''']
txt_file_write(sux_eng_dict_name,l)
